# %% [markdown]
# # ML in Cybersecurity: Project II
#
# ## Team
#   * **Team name**: *Good Fellows*
#   * **Members**:  *fill this in. format: Md. Abdul Kadir (s8mdkadi@stud.uni-saarland.de), Hasan Md Tusfiqur Alam (s8haalam@stud.uni-saarland.de), ...*
#
#
# ## Logistics
#   * **Due date**: 28th November 2019, 13:59:59 (right before the lecture)
#   * Email the completed notebook to: `mlcysec_ws1920_staff@lists.cispa.saarland`
#   * Complete this in **teams of 3**
#   * Feel free to use the course [mailing list](https://lists.cispa.saarland/listinfo/mlcysec_ws1920_stud) to discuss.
#
# ## Timeline
#   * 14-Nov-2019: Project 2 hand-out
#   * **28-Nov-2019** (13:59:59): Email completed notebook
#   * 5-Nov-2019: Project 2 discussion and summary
#
#
# ## About this Project
# In this project, you will explore an application of ML to a popular task in cybersecurity: malware classification.
# You will be presented with precomputed behaviour analysis reports of thousands of program binaries, many of which are malwares.
# Your goal will be train a malware detector using this behavioural reports.
#
#
# ## A Note on Grading
# The grading for this project will depend on:
#  1. Vectorizing Inputs
#    * Obtaining a reasonable vectorized representations of the input data (a file containing a sequence of system calls)
#    * Understanding the influence these representations have on your model
#  1. Classification Model
#    * Following a clear ML pipeline
#    * Obtaining reasonable performances (>60\%) on held-out test set
#    * Choice of evaluation metric
#    * Visualizing loss/accuracy curves
#  1. Analysis
#    * Which methods (input representations/ML models) work better than the rest and why?
#    * Which hyper-parameters and design-choices were important in each of your methods?
#    * Quantifying influence of these hyper-parameters on loss and/or validation accuracies
#    * Trade-offs between methods, hyper-parameters, design-choices
#    * Anything else you find interesting (this part is open-ended)
#
#
# ## Grading Details
#  * 40 points: Vectorizing input data (each input = behaviour analysis file in our case)
#  * 40 points: Training a classification model
#  * 15 points: Analysis/Discussion
#  * 5 points: Clean code
#
# ## Filling-in the Notebook
# You'll be submitting this very notebook that is filled-in with your code and analysis. Make sure you submit one that has been previously executed in-order. (So that results/graphs are already visible upon opening it).
#
# The notebook you submit **should compile** (or should be self-contained and sufficiently commented). Check tutorial 1 on how to set up the Python3 environment.
#
#
# **The notebook is your project report. So, to make the report readable, omit code for techniques/models/things that did not work. You can use final summary to provide report about these codes.**
#
# It is extremely important that you **do not** re-order the existing sections. Apart from that, the code blocks that you need to fill-in are given by:
# ```
# #
# #
# # ------- Your Code -------
# #
# #
# ```
# Feel free to break this into multiple-cells. It's even better if you interleave explanations and code-blocks so that the entire notebook forms a readable "story".
#
#
# ## Code of Honor
# We encourage discussing ideas and concepts with other students to help you learn and better understand the course content. However, the work you submit and present **must be original** and demonstrate your effort in solving the presented problems. **We will not tolerate** blatantly using existing solutions (such as from the internet), improper collaboration (e.g., sharing code or experimental data between groups) and plagiarism. If the honor code is not met, no points will be awarded.
#
#
#  ## Versions
#   * v1.1: Updated deadline
#   * v1.0: Initial notebook
#
#   ---

# %%
import time 
 
import numpy as np 
import matplotlib.pyplot as plt 

import json 
import time 
import pickle 
import sys 
import csv 
import os 
import os.path as osp 
import shutil 
import pathlib
from pathlib import Path
import itertools  
import collections 
from IPython.display import display, HTML
from livelossplot import PlotLosses
 
# %matplotlib inline 
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots 
plt.rcParams['image.interpolation'] = 'nearest' 
plt.rcParams['image.cmap'] = 'gray' 
 
# for auto-reloading external modules 
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython 
# %load_ext autoreload
# %autoreload 2

# %%
# Some suggestions of our libraries that might be helpful for this project
from collections import Counter          # an even easier way to count
from multiprocessing import Pool         # for multiprocessing
from tqdm import tqdm                    # fancy progress bars

# Load other libraries here.
# Keep it minimal! We should be easily able to reproduce your code.
# We only support sklearn and pytorch.


# We preload pytorch as an example
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, TensorDataset
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
compute_mode = 'cpu'

if compute_mode == 'cpu':
    device = torch.device('cpu')
elif compute_mode == 'gpu':
    # If you are using pytorch on the GPU cluster, you have to manually specify which GPU device to use
    # It is extremely important that you *do not* spawn multi-GPU jobs.
    os.environ["CUDA_VISIBLE_DEVICES"] = '2'    # Set device ID here
    device = torch.device('cuda')
else:
    raise ValueError('Unrecognized compute mode')

# %% [markdown]
# # Setup
#
#   * Download the datasets: [train](https://nextcloud.mpi-klsb.mpg.de/index.php/s/pJrRGzm2So2PMZm) (128M) and [test](https://nextcloud.mpi-klsb.mpg.de/index.php/s/zN3yeWzQB3i5WqE) (92M)
#   * Unpack them under `./data/train` and `./data/test`

# %%
# Check that you are prepared with the data
! printf '# train examples (Should be 13682) : '; ls data/train | wc -l
! printf '# test  examples (Should be 10000) : '; ls data/test | wc -l
# Out:
# # train examples (Should be 13682) :    13682
# # test  examples (Should be 10000) :    10000

# %% [markdown]
# Now that you're set, let's briefly look at the data you have been handed.
# Each file encodes the behavior report of a program (potentially a malware), using an encoding scheme called "The Malware Instruction Set" (MIST for short).
# At this point, we highly recommend you briefly read-up Sec. 2 of the [MIST](http://www.mlsec.org/malheur/docs/mist-tr.pdf) documentation.
#
# You will find each file named as `filename.<malwarename>`:
# ```
# » ls data/train | head
# 00005ecc06ae3e489042e979717bb1455f17ac9d.NothingFound
# 0008e3d188483aeae0de62d8d3a1479bd63ed8c9.Basun
# 000d2eea77ee037b7ef99586eb2f1433991baca9.Patched
# 000d996fa8f3c83c1c5568687bb3883a543ec874.Basun
# 0010f78d3ffee61101068a0722e09a98959a5f2c.Basun
# 0013cd0a8febd88bfc4333e20486bd1a9816fcbf.Basun
# 0014aca72eb88a7f20fce5a4e000c1f7fff4958a.Texel
# 001ffc75f24a0ae63a7033a01b8152ba371f6154.Texel
# 0022d6ba67d556b931e3ab26abcd7490393703c4.Basun
# 0028c307a125cf0fdc97d7a1ffce118c6e560a70.Swizzor
# ...
# ```
# and within each file, you will see a sequence of individual systems calls monitored duing the run-time of the binary - a malware named 'Basun' in the case:
# ```
# » head data/train/000d996fa8f3c83c1c5568687bb3883a543ec874.Basun
# # process 000006c8 0000066a 022c82f4 00000000 thread 0001 #
# 02 01 | 000006c8 0000066a 00015000
# 02 02 | 00006b2c 047c8042 000b9000
# 02 02 | 00006b2c 047c8042 00108000
# 02 02 | 00006b2c 047c8042 00153000
# 02 02 | 00006b2c 047c8042 00091000
# 02 02 | 00006b2c 047c8042 00049000
# 02 02 | 00006b2c 047c8042 000aa000
# 02 02 | 00006b2c 047c8042 00092000
# 02 02 | 00006b2c 047c8042 00011000
# ...
# ```
# (**Note**: Please ignore the first line that begins with `# process ...`.)
#
# Your task in this project is to train a malware detector, which given the sequence of system calls (in the MIST-formatted file like above), predicts one of 10 classes: `{ Agent, Allaple, AutoIt, Basun, NothingFound, Patched, Swizzor, Texel, VB, Virut }`, where `NothingFound` roughly represents no malware is present.
# In terms of machine learning terminology, your malware detector $F: X \rightarrow Y$ should learn a mapping from the MIST-encoded behaviour report (the input $x \in X$) to the malware class $y \in Y$.
#
# Consequently, you will primarily tackle two challenges in this project:
#   1. "Vectorizing" the input data i.e., representing each input (file) as a tensor
#   1. Training an ML model
#
#
# ### Some tips:
#   * Begin with an extremely simple representation/ML model and get above chance-level classification performance
#   * Choose your evaluation metric wisely
#   * Save intermediate computations (e.g., a token to index mapping). This will avoid you parsing the entire dataset for every experiment
#   * Try using `multiprocessing.Pool` to parallelize your `for` loops

# %% [markdown]
# ---

# %% [markdown]
# # 1. Vectorize Data

# %% [markdown]
# ## 1.a. Load Raw Data

# %%
def file_load_kernel(filepath):
    '''Given a filepath, returns (content, classname), where content = [list of lines in file]'''
    
    # Parse the file name and identify the class name.
    label = filepath.split('.')[2]
    
    # Read the file 
    with open(filepath, 'r') as file :
        lines = file.read().splitlines()
    if '# process' in lines[0] :
        del lines[0]
    
    
    # Remove the firstline start with "# process"
    
    # Convert text file to list , content of list is the lines of the textfile.
    
    
    
    return lines, label

def file_load_kernel_token(filepath):
    '''Given a filepath, returns (content, classname), where content = [list of lines in file]'''
    #
    #
    # ------- Your Code -------
    #
    #
    
    # Parse the file name and identify the class name.
    label = filepath.split('.')[2]
    
    # Read the file 
    with open(filepath, 'r') as file :
        lines = file.read().splitlines()
    if '# process' in lines[0] :
        del lines[0]
    
    
    # Remove the firstline start with "# process"
    
    # Convert text file to list , content of list is the lines of the textfile.
    
    
    
    return lines

def handler(function, data, workers=6):
    
    with Pool(workers) as pool:
        #pool.map(cycle, offsets)
        r = pool.map(function, data)
    return r

def load_data(data_path, nworkers=6):
    '''Returns each data sample as a tuple (x, y), x = sequence of strings (i.e., syscalls), y = malware program class'''

    files = os.listdir(data_path)
    raw_data_samples = []
    
    #file_chunks = [tokens[x:x+1000] for x in range(0, len(tokens), 1000)]
    
    # Removing the empty index
    file_addresses = []
    del files[-1]
    i = 1
    print('Total file is: ', len(files) )
    y_list = []
    for file in files:
        y_val = file.split('.')[-1]
        y_list.append(y_val)
        file_addresses.append (os.path.join(data_path,file))
#         print('Reading file: ', i)
        i += 1
        if i> 2000:
            break #comment this to load whole dataset

    #print(file_addresses)
#     raw_data_samples = handler(file_load_kernel,file_addresses,workers=4)
    return file_addresses, y_list

# %%
tfidf_vectorizer =  TfidfVectorizer(input='filename', token_pattern='.*\r')

training_files, train_y_list = load_data('./data/train', nworkers=4)
train_tfidf_data_x = tfidf_vectorizer.fit_transform(training_files)
# Out:
# Total file is:  13681

# %%
# Test 

#print(file_load_kernel('./data/train/fffb9be0177ac57f213bc089b319582936a5bd08.NothingFound'))
#print(load_data('./data/train', nworkers=4)[0])

test_files, test_y_list = load_data('./data/test', nworkers=4)

test_tfidf_data_x = tfidf_vectorizer.fit_transform(test_files)
# Out:
# Total file is:  9999

# %%
# print(tfidf_data.toarray())
y_list = np.asarray(y_list)
x_mat = tfidf_data.toarray()
x_torch = torch.from_numpy(x_mat)

train_x_numpy = train_tfidf_data_x.toarray()
train_x_torch = torch.FloatTensor(train_x_numpy)

# test_x_numpy = test_tfidf_data_x.toarray()
# test_x_torch = torch.FloatTensor(test_x_numpy)


# print(tfidf_vectorizer.get_feature_names())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-105-8f704cd6c6f6> in <module>
#       1 # print(tfidf_data.toarray())
#       2 y_list = np.asarray(y_list)
# ----> 3 x_mat = tfidf_data.toarray()
#       4 x_torch = torch.from_numpy(x_mat)
#       5
#
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#     960         if out is None and order is None:
#     961             order = self._swap('cf')[0]
# --> 962         out = self._process_toarray_args(order, out)
#     963         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#     964             raise ValueError('Output array must be C or F contiguous')
#
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1185             return out
#    1186         else:
# -> 1187             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1188
#    1189
#
# MemoryError:

# %%
def one_hot_encode(integer_encoded):
    
    onehot_encoder = OneHotEncoder(sparse=False)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_encoded = onehot_encoder.fit_transform(integer_encoded)
    return onehot_encoded

label_encoder = LabelEncoder()
train_y_encoded = label_encoder.fit_transform(train_y_list)
train_y_encoded = one_hot_encode(train_y_encoded)

test_y_encoded = label_encoder.fit_transform(test_y_list)
test_y_encoded = one_hot_encode(test_y_encoded)
# Out:
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 1.b. Vectorize: Setup
#
# Make one pass over the inputs to identify relevant features/tokens.
#
# Suggestion:
#   - identify tokens (e.g., unigrams, bigrams)
#   - create a token -> index (int) mapping. Note that you might have a >10K unique tokens. So, you will have to choose a suitable "vocabulary" size.

# %%
# Feel free to edit anything in this block
def countFrequency(my_list): 
      # This taking long time to read
    # Creating an empty dictionary  
    i = 1
    freq = {} 
    for items in my_list:
        freq[items] = my_list.count(items) 
    
    return freq 



# it use multiple files to create a frequency counter
def load_multiple_files_frequecy_list(file_list):
    raw_data_samples = handler(file_load_kernel_token,file_list, workers=6)
    print('raw data collection fininshed')
    print('raw data length in each chunk', len(raw_data_samples))
    list_of_dict = handler(countFrequency, raw_data_samples, workers=6) # This line taking longer time 
    print('multiprocess finished')
    return  {k: v for d in list_of_dict for k, v in d.items()}
    

def get_key_idx_map(counter, vocab_size, ukn_token='_ukn_'):
    # counter is a mapping: token -> count
    # build vectorizer using vocab_size most common elements
    counter_unk = counter
    idx_to_key = {}
    key_to_idx = {}
    
    
    if len(counter)< vocab_size:
        counter_unk.update({ukn_token:(vocab_size - len(counter))})
        
    counter_unk = dict(sorted(counter_unk.items(), key=lambda x: x[1], reverse=True))
    
    for i in range(len(counter_unk)):
        idx_to_key.update({i:list(counter_unk.keys())[i]})
        key_to_idx.update({list(counter_unk.keys())[i]:i})
    
    #key_to_idx, idx_to_key = dict(), dict()
    return key_to_idx, idx_to_key
# Helper class to get all text files in a list
def get_all_file_address(directory):
    files = os.listdir(directory)
    files = [os.path.join(directory,file) for file in files]
    
    return files
# helper class to get token count

    

def get_class_key_index_map(class_counter):
  #  { 'Agent':0, 'Allaple':1, 'AutoIt': 2, 'Basun':3, 'NothingFound':4, 'Patched': 5, 'Swizzor':6, 'Texel':7, 'VB': 8, 'Virut':9 }
    class_index = class_counter
    index_class = dict((v,k) for k,v in class_index.items())
    nb_classes = len(class_counter)
    targets = np.array([class_counter.keys()]).reshape(-1)
    one_hot_targets = np.eye(nb_classes).tolist()
    class_index = dict(zip([*class_index], one_hot_targets))
    return class_index, index_class

# %%
# Test
#my_map = {'a': 1, 'b': 2}
#print(get_key_idx_map(my_map,4))
classes = { 'Agent':0, 'Allaple':1, 'AutoIt': 2, 'Basun':3, 'NothingFound':4, 'Patched': 5, 'Swizzor':6, 'Texel':7, 'VB': 8, 'Virut':9 }
class_onehot, index_class = get_class_key_index_map(classes)
print(index_class)
#print(index_class)
# Out:
# {0: 'Agent', 1: 'Allaple', 2: 'AutoIt', 3: 'Basun', 4: 'NothingFound', 5: 'Patched', 6: 'Swizzor', 7: 'Texel', 8: 'VB', 9: 'Virut'}

# %%
'''# List of all files 

training_files = get_all_file_address('./data/train')
print(len(training_files))
multiple_training_file_chunk = [training_files[x:x+200] for x in range(0, len(training_files),200)]
print(len(multiple_training_file_chunk))

print("length of each chunk will oprocessed in pool", len(multiple_training_file_chunk[0]))
# Reading token count using multiprocessing handaller 
#list_dict_count = handler(load_multiple_files_frequecy_list, multiple_training_file_chunk, workers=4)

print(len(load_multiple_files_frequecy_list(multiple_training_file_chunk[0])))

count_dict = {}

#for l in multiple_training_file_chunk:
#    count_dict = {**count_dict, **load_multiple_files_frequecy_list(l)}
#    print('counting the key')
    

#print(len(count_dict))
'''
# Out:
# '# List of all files \n\ntraining_files = get_all_file_address(\'./data/train\')\nprint(len(training_files))\nmultiple_training_file_chunk = [training_files[x:x+200] for x in range(0, len(training_files),200)]\nprint(len(multiple_training_file_chunk))\n\nprint("length of each chunk will oprocessed in pool", len(multiple_training_file_chunk[0]))\n# Reading token count using multiprocessing handaller \n#list_dict_count = handler(load_multiple_files_frequecy_list, multiple_training_file_chunk, workers=4)\n\nprint(len(load_multiple_files_frequecy_list(multiple_training_file_chunk[0])))\n\ncount_dict = {}\n\n#for l in multiple_training_file_chunk:\n#    count_dict = {**count_dict, **load_multiple_files_frequecy_list(l)}\n#    print(\'counting the key\')\n    \n\n#print(len(count_dict))\n'

# %%
# Feel free to edit anything in this block
# Count maximum vocab size

# Comment this after a full run. 
training_data = load_data('./data/train', nworkers=4)
    
print('training data reading finish')
tokens = []
for pairs in training_data:
    tokens = tokens + pairs[0]

token_chunks = [tokens[x:x+1000] for x in range(0, len(tokens), 1000)]

print('token generation is done')
#print(tokens)
MAX_VOCAB_SIZE = len(set(tokens)) + 100 # Assumtion 

token_counter =  handler(countFrequency,token_chunks)
print('tocken frequency counting using multiprocessor is finished')
combined_token_dict = {k: v for d in token_counter for k, v in d.items()}

token_to_idx = combined_token_dict.copy()
del combined_token_dict
token_to_idx.update({'_ukn_': 100})
#print(token_to_idx)
#idx_to_token = combined_token_dict
#print(token_counter)
print('frequency counting is done')
print()
#token_to_idx, idx_to_token = get_key_idx_map(combined_token_dict, MAX_VOCAB_SIZE)    
# Save vocab to file

out_path = 'application_vocab_{}.pkl'.format(MAX_VOCAB_SIZE)
with open(out_path, 'wb') as wf:
    dct = {'token_to_idx': token_to_idx}#,
         # 'idx_to_token': idx_to_token}
    pickle.dump(dct, wf)
# Out:
# Total file is:  13681
# Reading file:  1
# Reading file:  2
# Reading file:  3
# Reading file:  4
# Reading file:  5
# Reading file:  6
# Reading file:  7
# Reading file:  8
# Reading file:  9
# Reading file:  10
# Reading file:  11
# Reading file:  12
# Reading file:  13
# Reading file:  14
# Reading file:  15
# Reading file:  16
# Reading file:  17
# Reading file:  18
# Reading file:  19
# Reading file:  20

# %%
#print(token_to_idx)
#print(idx_to_token)

# %% [markdown]
# ## 1.c. Vectorize Data
#
# Use the (token $\rightarrow$ index) mapping you created before to vectorize your data

# %%
#
#
# ------- Your Code -------
#
#
# Load the data from pickle file 

vectorized_file = open(out_path,'rb')  # CHNAGE THE NAME OF FILE
vectorizer_data = pickle.load(vectorized_file)
vectorized_file.close()
print(type(vectorizer_data))
# Out:
# <class 'dict'>

# %%
def vectorize_raw_samples(raw_samples, nworkers=4):
    vectorized_samples = []
    
    #
    #
    # ------- Your Code -------
    #
    #
    token_to_idx = vectorizer_data['token_to_idx']
    data = load_data(raw_samples, nworkers)
    
    #tokens_list = list(token_to_idx.keys())
    #print(tokens_list)
    
    
    
    for l in data:
        temp_list = [0 for i in range(len(token_to_idx))]
        
        
        
        
        for i in l[0]:
            # The method is called bag of words
            index = token_to_idx.get(i)#[token_to_idx[i]]
            if index:
                temp_list[index] = temp_list[index] + 1
                #temp_list.append(index)
            else:
                temp_list[token_to_idx.get('_ukn_')] = temp_list[token_to_idx.get('_ukn_')] + 1
                #temp_list.append(token_to_idx.get('_ukn_'))
        if(class_onehot.get(l[1])):
            vectorized_samples.append((temp_list, class_onehot.get(l[1])))
        else:
            vectorized_samples.append((temp_list, class_onehot.get( 'NothingFound'))) 
        #vectorized_samples.append(([token_to_idx.get(i) if token_to_idx.get(i) else token_to_idx.get('_ukn_') for  i in l[0]], l[1]))
    
    
    return vectorized_samples

# %%
def store_as_pickle(file_name, data):
    with open(file_name, 'wb') as handle:
        pickle.dump(data, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
def load_from_pickle(file_name):
    with open(file_name, "rb") as input_file:
        data = pickle.load(input_file)
        return data

# %%
print('=> Processing: Train')
train_raw_samples = './data/train'
test_raw_samples = './data/test'
train_data = vectorize_raw_samples(train_raw_samples) # comment this line after first run
print('=> Processing: Test')
test_data = vectorize_raw_samples(test_raw_samples) # Comment this line after first run
#train_data = load_from_pickle('training_data.pickle')
#test_data = load_from_pickle('test_data.pickle')
#print(train_data)
#print(test_data[0])

store_as_pickle('training_data.pickle', train_data)
store_as_pickle('test_data.pickle', test_data)
# Out:
# => Processing: Train
# Total file is:  13681
# Reading file:  1
# Reading file:  2
# Reading file:  3
# Reading file:  4
# Reading file:  5
# Reading file:  6
# Reading file:  7
# Reading file:  8
# Reading file:  9
# Reading file:  10
# Reading file:  11
# Reading file:  12
# Reading file:  13
# Reading file:  14
# Reading file:  15
# Reading file:  16
# Reading file:  17
# Reading file:  18
# Reading file:  19
# Reading file:  20
# Reading file:  21
# Reading file:  22
# Reading file:  23
# Reading file:  24
# Reading file:  25
# Reading file:  26
# Reading file:  27
# Reading file:  28
# Reading file:  29
# Reading file:  30
# Reading file:  31
# Reading file:  32
# Reading file:  33
# Reading file:  34
# Reading file:  35
# Reading file:  36
# Reading file:  37
# Reading file:  38
# Reading file:  39
# Reading file:  40
# Reading file:  41
# Reading file:  42
# Reading file:  43
# Reading file:  44
# Reading file:  45
# Reading file:  46
# Reading file:  47
# Reading file:  48
# Reading file:  49
# Reading file:  50
# Reading file:  51
# Reading file:  52
# Reading file:  53
# Reading file:  54
# Reading file:  55
# Reading file:  56
# Reading file:  57
# Reading file:  58
# Reading file:  59
# Reading file:  60
# Reading file:  61
# Reading file:  62
# Reading file:  63
# Reading file:  64
# Reading file:  65
# Reading file:  66
# Reading file:  67
# Reading file:  68
# Reading file:  69
# Reading file:  70
# Reading file:  71
# Reading file:  72
# Reading file:  73
# Reading file:  74
# Reading file:  75
# Reading file:  76
# Reading file:  77
# Reading file:  78
# Reading file:  79
# Reading file:  80
# Reading file:  81
# Reading file:  82
# Reading file:  83
# Reading file:  84
# Reading file:  85
# Reading file:  86
# Reading file:  87
# Reading file:  88
# Reading file:  89
# Reading file:  90
# Reading file:  91
# Reading file:  92
# Reading file:  93
# Reading file:  94
# Reading file:  95
# Reading file:  96
# Reading file:  97
# Reading file:  98
# Reading file:  99
# Reading file:  100
# Reading file:  101
# Reading file:  102
# Reading file:  103
# Reading file:  104
# Reading file:  105
# Reading file:  106
# Reading file:  107
# Reading file:  108
# Reading file:  109
# Reading file:  110
# Reading file:  111
# Reading file:  112
# Reading file:  113
# Reading file:  114
# Reading file:  115
# Reading file:  116
# Reading file:  117
# Reading file:  118
# Reading file:  119
# Reading file:  120
# Reading file:  121
# Reading file:  122
# Reading file:  123
# Reading file:  124
# Reading file:  125
# Reading file:  126
# Reading file:  127
# Reading file:  128
# Reading file:  129
# Reading file:  130
# Reading file:  131
# Reading file:  132
# Reading file:  133
# Reading file:  134
# Reading file:  135
# Reading file:  136
# Reading file:  137
# Reading file:  138
# Reading file:  139
# Reading file:  140
# Reading file:  141
# Reading file:  142
# Reading file:  143
# Reading file:  144
# Reading file:  145
# Reading file:  146
# Reading file:  147
# Reading file:  148
# Reading file:  149
# Reading file:  150
# Reading file:  151
# Reading file:  152
# Reading file:  153
# Reading file:  154
# Reading file:  155
# Reading file:  156
# Reading file:  157
# Reading file:  158
# Reading file:  159
# Reading file:  160
# Reading file:  161
# Reading file:  162
# Reading file:  163
# Reading file:  164
# Reading file:  165
# Reading file:  166
# Reading file:  167
# Reading file:  168
# Reading file:  169
# Reading file:  170
# Reading file:  171
# Reading file:  172
# Reading file:  173
# Reading file:  174
# Reading file:  175
# Reading file:  176
# Reading file:  177
# Reading file:  178
# Reading file:  179
# Reading file:  180
# Reading file:  181
# Reading file:  182
# Reading file:  183
# Reading file:  184
# Reading file:  185
# Reading file:  186
# Reading file:  187
# Reading file:  188
# Reading file:  189
# Reading file:  190
# Reading file:  191
# Reading file:  192
# Reading file:  193
# Reading file:  194
# Reading file:  195
# Reading file:  196
# Reading file:  197
# Reading file:  198
# Reading file:  199
# Reading file:  200
# Reading file:  201
# Reading file:  202
# Reading file:  203
# Reading file:  204
# Reading file:  205
# Reading file:  206
# Reading file:  207
# Reading file:  208
# Reading file:  209
# Reading file:  210
# Reading file:  211
# Reading file:  212
# Reading file:  213
# Reading file:  214
# Reading file:  215
# Reading file:  216
# Reading file:  217
# Reading file:  218
# Reading file:  219
# Reading file:  220
# Reading file:  221
# Reading file:  222
# Reading file:  223
# Reading file:  224
# Reading file:  225
# Reading file:  226
# Reading file:  227
# Reading file:  228
# Reading file:  229
# Reading file:  230
# Reading file:  231
# Reading file:  232
# Reading file:  233
# Reading file:  234
# Reading file:  235
# Reading file:  236
# Reading file:  237
# Reading file:  238
# Reading file:  239
# Reading file:  240
# Reading file:  241
# Reading file:  242
# Reading file:  243
# Reading file:  244
# Reading file:  245
# Reading file:  246
# Reading file:  247
# Reading file:  248
# Reading file:  249
# Reading file:  250
# Reading file:  251
# Reading file:  252
# Reading file:  253
# Reading file:  254
# Reading file:  255
# Reading file:  256
# Reading file:  257
# Reading file:  258
# Reading file:  259
# Reading file:  260
# Reading file:  261
# Reading file:  262
# Reading file:  263
# Reading file:  264
# Reading file:  265
# Reading file:  266
# Reading file:  267
# Reading file:  268
# Reading file:  269
# Reading file:  270
# Reading file:  271
# Reading file:  272
# Reading file:  273
# Reading file:  274
# Reading file:  275
# Reading file:  276
# Reading file:  277
# Reading file:  278
# Reading file:  279
# Reading file:  280
# Reading file:  281
# Reading file:  282
# Reading file:  283
# Reading file:  284
# Reading file:  285
# Reading file:  286
# Reading file:  287
# Reading file:  288
# Reading file:  289
# Reading file:  290
# Reading file:  291
# Reading file:  292
# Reading file:  293
# Reading file:  294
# Reading file:  295
# Reading file:  296
# Reading file:  297
# Reading file:  298
# Reading file:  299
# Reading file:  300
# Reading file:  301
# Reading file:  302
# Reading file:  303
# Reading file:  304
# Reading file:  305
# Reading file:  306
# Reading file:  307
# Reading file:  308
# Reading file:  309
# Reading file:  310
# Reading file:  311
# Reading file:  312
# Reading file:  313
# Reading file:  314
# Reading file:  315
# Reading file:  316
# Reading file:  317
# Reading file:  318
# Reading file:  319
# Reading file:  320
# Reading file:  321
# Reading file:  322
# Reading file:  323
# Reading file:  324
# Reading file:  325
# Reading file:  326
# Reading file:  327
# Reading file:  328
# Reading file:  329
# Reading file:  330
# Reading file:  331
# Reading file:  332
# Reading file:  333
# Reading file:  334
# Reading file:  335
# Reading file:  336
# Reading file:  337
# Reading file:  338
# Reading file:  339
# Reading file:  340
# Reading file:  341
# Reading file:  342
# Reading file:  343
# Reading file:  344
# Reading file:  345
# Reading file:  346
# Reading file:  347
# Reading file:  348
# Reading file:  349
# Reading file:  350
# Reading file:  351
# Reading file:  352
# Reading file:  353
# Reading file:  354
# Reading file:  355
# Reading file:  356
# Reading file:  357
# Reading file:  358
# Reading file:  359
# Reading file:  360
# Reading file:  361
# Reading file:  362
# Reading file:  363
# Reading file:  364
# Reading file:  365
# Reading file:  366
# Reading file:  367
# Reading file:  368
# Reading file:  369
# Reading file:  370
# Reading file:  371
# Reading file:  372
# Reading file:  373
# Reading file:  374
# Reading file:  375
# Reading file:  376
# Reading file:  377
# Reading file:  378
# Reading file:  379
# Reading file:  380
# Reading file:  381
# Reading file:  382
# Reading file:  383
# Reading file:  384
# Reading file:  385
# Reading file:  386
# Reading file:  387
# Reading file:  388
# Reading file:  389
# Reading file:  390
# Reading file:  391
# Reading file:  392
# Reading file:  393
# Reading file:  394
# Reading file:  395
# Reading file:  396
# Reading file:  397
# Reading file:  398
# Reading file:  399
# Reading file:  400
# Reading file:  401
# Reading file:  402
# Reading file:  403
# Reading file:  404
# Reading file:  405
# Reading file:  406
# Reading file:  407
# Reading file:  408
# Reading file:  409
# Reading file:  410
# Reading file:  411
# Reading file:  412
# Reading file:  413
# Reading file:  414
# Reading file:  415
# Reading file:  416
# Reading file:  417
# Reading file:  418
# Reading file:  419
# Reading file:  420
# Reading file:  421
# Reading file:  422
# Reading file:  423
# Reading file:  424
# Reading file:  425
# Reading file:  426
# Reading file:  427
# Reading file:  428
# Reading file:  429
# Reading file:  430
# Reading file:  431
# Reading file:  432
# Reading file:  433
# Reading file:  434
# Reading file:  435
# Reading file:  436
# Reading file:  437
# Reading file:  438
# Reading file:  439
# Reading file:  440
# Reading file:  441
# Reading file:  442
# Reading file:  443
# Reading file:  444
# Reading file:  445
# Reading file:  446
# Reading file:  447
# Reading file:  448
# Reading file:  449
# Reading file:  450
# Reading file:  451
# Reading file:  452
# Reading file:  453
# Reading file:  454
# Reading file:  455
# Reading file:  456
# Reading file:  457
# Reading file:  458
# Reading file:  459
# Reading file:  460
# Reading file:  461
# Reading file:  462
# Reading file:  463
# Reading file:  464
# Reading file:  465
# Reading file:  466
# Reading file:  467
# Reading file:  468
# Reading file:  469
# Reading file:  470
# Reading file:  471
# Reading file:  472
# Reading file:  473
# Reading file:  474
# Reading file:  475
# Reading file:  476
# Reading file:  477
# Reading file:  478
# Reading file:  479
# Reading file:  480
# Reading file:  481
# Reading file:  482
# Reading file:  483
# Reading file:  484
# Reading file:  485
# Reading file:  486
# Reading file:  487
# Reading file:  488
# Reading file:  489
# Reading file:  490
# Reading file:  491
# Reading file:  492
# Reading file:  493
# Reading file:  494
# Reading file:  495
# Reading file:  496
# Reading file:  497
# Reading file:  498
# Reading file:  499
# Reading file:  500
# Reading file:  501
# Reading file:  502
# Reading file:  503
# Reading file:  504
# Reading file:  505
# Reading file:  506
# Reading file:  507
# Reading file:  508
# Reading file:  509
# Reading file:  510
# Reading file:  511
# Reading file:  512
# Reading file:  513
# Reading file:  514
# Reading file:  515
# Reading file:  516
# Reading file:  517
# Reading file:  518
# Reading file:  519
# Reading file:  520
# Reading file:  521
# Reading file:  522
# Reading file:  523
# Reading file:  524
# Reading file:  525
# Reading file:  526
# Reading file:  527
# Reading file:  528
# Reading file:  529
# Reading file:  530
# Reading file:  531
# Reading file:  532
# Reading file:  533
# Reading file:  534
# Reading file:  535
# Reading file:  536
# Reading file:  537
# Reading file:  538
# Reading file:  539
# Reading file:  540
# Reading file:  541
# Reading file:  542
# Reading file:  543
# Reading file:  544
# Reading file:  545
# Reading file:  546
# Reading file:  547
# Reading file:  548
# Reading file:  549
# Reading file:  550
# Reading file:  551
# Reading file:  552
# Reading file:  553
# Reading file:  554
# Reading file:  555
# Reading file:  556
# Reading file:  557
# Reading file:  558
# Reading file:  559
# Reading file:  560
# Reading file:  561
# Reading file:  562
# Reading file:  563
# Reading file:  564
# Reading file:  565
# Reading file:  566
# Reading file:  567
# Reading file:  568
# Reading file:  569
# Reading file:  570
# Reading file:  571
# Reading file:  572
# Reading file:  573
# Reading file:  574
# Reading file:  575
# Reading file:  576
# Reading file:  577
# Reading file:  578
# Reading file:  579
# Reading file:  580
# Reading file:  581
# Reading file:  582
# Reading file:  583
# Reading file:  584
# Reading file:  585
# Reading file:  586
# Reading file:  587
# Reading file:  588
# Reading file:  589
# Reading file:  590
# Reading file:  591
# Reading file:  592
# Reading file:  593
# Reading file:  594
# Reading file:  595
# Reading file:  596
# Reading file:  597
# Reading file:  598
# Reading file:  599
# Reading file:  600
# Reading file:  601
# Reading file:  602
# Reading file:  603
# Reading file:  604
# Reading file:  605
# Reading file:  606
# Reading file:  607
# Reading file:  608
# Reading file:  609
# Reading file:  610
# Reading file:  611
# Reading file:  612
# Reading file:  613
# Reading file:  614
# Reading file:  615
# Reading file:  616
# Reading file:  617
# Reading file:  618
# Reading file:  619
# Reading file:  620
# Reading file:  621
# Reading file:  622
# Reading file:  623
# Reading file:  624
# Reading file:  625
# Reading file:  626
# Reading file:  627
# Reading file:  628
# Reading file:  629
# Reading file:  630
# Reading file:  631
# Reading file:  632
# Reading file:  633
# Reading file:  634
# Reading file:  635
# Reading file:  636
# Reading file:  637
# Reading file:  638
# Reading file:  639
# Reading file:  640
# Reading file:  641
# Reading file:  642
# Reading file:  643
# Reading file:  644
# Reading file:  645
# Reading file:  646
# Reading file:  647
# Reading file:  648
# Reading file:  649
# Reading file:  650
# Reading file:  651
# Reading file:  652
# Reading file:  653
# Reading file:  654
# Reading file:  655
# Reading file:  656
# Reading file:  657
# Reading file:  658
# Reading file:  659
# Reading file:  660
# Reading file:  661
# Reading file:  662
# Reading file:  663
# Reading file:  664
# Reading file:  665
# Reading file:  666
# Reading file:  667
# Reading file:  668
# Reading file:  669
# Reading file:  670
# Reading file:  671
# Reading file:  672
# Reading file:  673
# Reading file:  674
# Reading file:  675
# Reading file:  676
# Reading file:  677
# Reading file:  678
# Reading file:  679
# Reading file:  680
# Reading file:  681
# Reading file:  682
# Reading file:  683
# Reading file:  684
# Reading file:  685
# Reading file:  686
# Reading file:  687
# Reading file:  688
# Reading file:  689
# Reading file:  690
# Reading file:  691
# Reading file:  692
# Reading file:  693
# Reading file:  694
# Reading file:  695
# Reading file:  696
# Reading file:  697
# Reading file:  698
# Reading file:  699
# Reading file:  700
# Reading file:  701
# Reading file:  702
# Reading file:  703
# Reading file:  704
# Reading file:  705
# Reading file:  706
# Reading file:  707
# Reading file:  708
# Reading file:  709
# Reading file:  710
# Reading file:  711
# Reading file:  712
# Reading file:  713
# Reading file:  714
# Reading file:  715
# Reading file:  716
# Reading file:  717
# Reading file:  718
# Reading file:  719
# Reading file:  720
# Reading file:  721
# Reading file:  722
# Reading file:  723
# Reading file:  724
# Reading file:  725
# Reading file:  726
# Reading file:  727
# Reading file:  728
# Reading file:  729
# Reading file:  730
# Reading file:  731
# Reading file:  732
# Reading file:  733
# Reading file:  734
# Reading file:  735
# Reading file:  736
# Reading file:  737
# Reading file:  738
# Reading file:  739
# Reading file:  740
# Reading file:  741
# Reading file:  742
# Reading file:  743
# Reading file:  744
# Reading file:  745
# Reading file:  746
# Reading file:  747
# Reading file:  748
# Reading file:  749
# Reading file:  750
# Reading file:  751
# Reading file:  752
# Reading file:  753
# Reading file:  754
# Reading file:  755
# Reading file:  756
# Reading file:  757
# Reading file:  758
# Reading file:  759
# Reading file:  760
# Reading file:  761
# Reading file:  762
# Reading file:  763
# Reading file:  764
# Reading file:  765
# Reading file:  766
# Reading file:  767
# Reading file:  768
# Reading file:  769
# Reading file:  770
# Reading file:  771
# Reading file:  772
# Reading file:  773
# Reading file:  774
# Reading file:  775
# Reading file:  776
# Reading file:  777
# Reading file:  778
# Reading file:  779
# Reading file:  780
# Reading file:  781
# Reading file:  782
# Reading file:  783
# Reading file:  784
# Reading file:  785
# Reading file:  786
# Reading file:  787
# Reading file:  788
# Reading file:  789
# Reading file:  790
# Reading file:  791
# Reading file:  792
# Reading file:  793
# Reading file:  794
# Reading file:  795
# Reading file:  796
# Reading file:  797
# Reading file:  798
# Reading file:  799
# Reading file:  800
# Reading file:  801
# Reading file:  802
# Reading file:  803
# Reading file:  804
# Reading file:  805
# Reading file:  806
# Reading file:  807
# Reading file:  808
# Reading file:  809
# Reading file:  810
# Reading file:  811
# Reading file:  812
# Reading file:  813
# Reading file:  814
# Reading file:  815
# Reading file:  816
# Reading file:  817
# Reading file:  818
# Reading file:  819
# Reading file:  820
# Reading file:  821
# Reading file:  822
# Reading file:  823
# Reading file:  824
# Reading file:  825
# Reading file:  826
# Reading file:  827
# Reading file:  828
# Reading file:  829
# Reading file:  830
# Reading file:  831
# Reading file:  832
# Reading file:  833
# Reading file:  834
# Reading file:  835
# Reading file:  836
# Reading file:  837
# Reading file:  838
# Reading file:  839
# Reading file:  840
# Reading file:  841
# Reading file:  842
# Reading file:  843
# Reading file:  844
# Reading file:  845
# Reading file:  846
# Reading file:  847
# Reading file:  848
# Reading file:  849
# Reading file:  850
# Reading file:  851
# Reading file:  852
# Reading file:  853
# Reading file:  854
# Reading file:  855
# Reading file:  856
# Reading file:  857
# Reading file:  858
# Reading file:  859
# Reading file:  860
# Reading file:  861
# Reading file:  862
# Reading file:  863
# Reading file:  864
# Reading file:  865
# Reading file:  866
# Reading file:  867
# Reading file:  868
# Reading file:  869
# Reading file:  870
# Reading file:  871
# Reading file:  872
# Reading file:  873
# Reading file:  874
# Reading file:  875
# Reading file:  876
# Reading file:  877
# Reading file:  878
# Reading file:  879
# Reading file:  880
# Reading file:  881
# Reading file:  882
# Reading file:  883
# Reading file:  884
# Reading file:  885
# Reading file:  886
# Reading file:  887
# Reading file:  888
# Reading file:  889
# Reading file:  890
# Reading file:  891
# Reading file:  892
# Reading file:  893
# Reading file:  894
# Reading file:  895
# Reading file:  896
# Reading file:  897
# Reading file:  898
# Reading file:  899
# Reading file:  900
# Reading file:  901
# Reading file:  902
# Reading file:  903
# Reading file:  904
# Reading file:  905
# Reading file:  906
# Reading file:  907
# Reading file:  908
# Reading file:  909
# Reading file:  910
# Reading file:  911
# Reading file:  912
# Reading file:  913
# Reading file:  914
# Reading file:  915
# Reading file:  916
# Reading file:  917
# Reading file:  918
# Reading file:  919
# Reading file:  920
# Reading file:  921
# Reading file:  922
# Reading file:  923
# Reading file:  924
# Reading file:  925
# Reading file:  926
# Reading file:  927
# Reading file:  928
# Reading file:  929
# Reading file:  930
# Reading file:  931
# Reading file:  932
# Reading file:  933
# Reading file:  934
# Reading file:  935
# Reading file:  936
# Reading file:  937
# Reading file:  938
# Reading file:  939
# Reading file:  940
# Reading file:  941
# Reading file:  942
# Reading file:  943
# Reading file:  944
# Reading file:  945
# Reading file:  946
# Reading file:  947
# Reading file:  948
# Reading file:  949
# Reading file:  950
# Reading file:  951
# Reading file:  952
# Reading file:  953
# Reading file:  954
# Reading file:  955
# Reading file:  956
# Reading file:  957
# Reading file:  958
# Reading file:  959
# Reading file:  960
# Reading file:  961
# Reading file:  962
# Reading file:  963
# Reading file:  964
# Reading file:  965
# Reading file:  966
# Reading file:  967
# Reading file:  968
# Reading file:  969
# Reading file:  970
# Reading file:  971
# Reading file:  972
# Reading file:  973
# Reading file:  974
# Reading file:  975
# Reading file:  976
# Reading file:  977
# Reading file:  978
# Reading file:  979
# Reading file:  980
# Reading file:  981
# Reading file:  982
# Reading file:  983
# Reading file:  984
# Reading file:  985
# Reading file:  986
# Reading file:  987
# Reading file:  988
# Reading file:  989
# Reading file:  990
# Reading file:  991
# Reading file:  992
# Reading file:  993
# Reading file:  994
# Reading file:  995
# Reading file:  996
# Reading file:  997
# Reading file:  998
# Reading file:  999
# Reading file:  1000
# Reading file:  1001
# Reading file:  1002
# Reading file:  1003
# Reading file:  1004
# Reading file:  1005
# Reading file:  1006
# Reading file:  1007
# Reading file:  1008
# Reading file:  1009
# Reading file:  1010
# Reading file:  1011
# Reading file:  1012
# Reading file:  1013
# Reading file:  1014
# Reading file:  1015
# Reading file:  1016
# Reading file:  1017
# Reading file:  1018
# Reading file:  1019
# Reading file:  1020
# Reading file:  1021
# Reading file:  1022
# Reading file:  1023
# Reading file:  1024
# Reading file:  1025
# Reading file:  1026
# Reading file:  1027
# Reading file:  1028
# Reading file:  1029
# Reading file:  1030
# Reading file:  1031
# Reading file:  1032
# Reading file:  1033
# Reading file:  1034
# Reading file:  1035
# Reading file:  1036
# Reading file:  1037
# Reading file:  1038
# Reading file:  1039
# Reading file:  1040
# Reading file:  1041
# Reading file:  1042
# Reading file:  1043
# Reading file:  1044
# Reading file:  1045
# Reading file:  1046
# Reading file:  1047
# Reading file:  1048
# Reading file:  1049
# Reading file:  1050
# Reading file:  1051
# Reading file:  1052
# Reading file:  1053
# Reading file:  1054
# Reading file:  1055
# Reading file:  1056
# Reading file:  1057
# Reading file:  1058
# Reading file:  1059
# Reading file:  1060
# Reading file:  1061
# Reading file:  1062
# Reading file:  1063
# Reading file:  1064
# Reading file:  1065
# Reading file:  1066
# Reading file:  1067
# Reading file:  1068
# Reading file:  1069
# Reading file:  1070
# Reading file:  1071
# Reading file:  1072
# Reading file:  1073
# Reading file:  1074
# Reading file:  1075
# Reading file:  1076
# Reading file:  1077
# Reading file:  1078
# Reading file:  1079
# Reading file:  1080
# Reading file:  1081
# Reading file:  1082
# Reading file:  1083
# Reading file:  1084
# Reading file:  1085
# Reading file:  1086
# Reading file:  1087
# Reading file:  1088
# Reading file:  1089
# Reading file:  1090
# Reading file:  1091
# Reading file:  1092
# Reading file:  1093
# Reading file:  1094
# Reading file:  1095
# Reading file:  1096
# Reading file:  1097
# Reading file:  1098
# Reading file:  1099
# Reading file:  1100
# Reading file:  1101
# Reading file:  1102
# Reading file:  1103
# Reading file:  1104
# Reading file:  1105
# Reading file:  1106
# Reading file:  1107
# Reading file:  1108
# Reading file:  1109
# Reading file:  1110
# Reading file:  1111
# Reading file:  1112
# Reading file:  1113
# Reading file:  1114
# Reading file:  1115
# Reading file:  1116
# Reading file:  1117
# Reading file:  1118
# Reading file:  1119
# Reading file:  1120
# Reading file:  1121
# Reading file:  1122
# Reading file:  1123
# Reading file:  1124
# Reading file:  1125
# Reading file:  1126
# Reading file:  1127
# Reading file:  1128
# Reading file:  1129
# Reading file:  1130
# Reading file:  1131
# Reading file:  1132
# Reading file:  1133
# Reading file:  1134
# Reading file:  1135
# Reading file:  1136
# Reading file:  1137
# Reading file:  1138
# Reading file:  1139
# Reading file:  1140
# Reading file:  1141
# Reading file:  1142
# Reading file:  1143
# Reading file:  1144
# Reading file:  1145
# Reading file:  1146
# Reading file:  1147
# Reading file:  1148
# Reading file:  1149
# Reading file:  1150
# Reading file:  1151
# Reading file:  1152
# Reading file:  1153
# Reading file:  1154
# Reading file:  1155
# Reading file:  1156
# Reading file:  1157
# Reading file:  1158
# Reading file:  1159
# Reading file:  1160
# Reading file:  1161
# Reading file:  1162
# Reading file:  1163
# Reading file:  1164
# Reading file:  1165
# Reading file:  1166
# Reading file:  1167
# Reading file:  1168
# Reading file:  1169
# Reading file:  1170
# Reading file:  1171
# Reading file:  1172
# Reading file:  1173
# Reading file:  1174
# Reading file:  1175
# Reading file:  1176
# Reading file:  1177
# Reading file:  1178
# Reading file:  1179
# Reading file:  1180
# Reading file:  1181
# Reading file:  1182
# Reading file:  1183
# Reading file:  1184
# Reading file:  1185
# Reading file:  1186
# Reading file:  1187
# Reading file:  1188
# Reading file:  1189
# Reading file:  1190
# Reading file:  1191
# Reading file:  1192
# Reading file:  1193
# Reading file:  1194
# Reading file:  1195
# Reading file:  1196
# Reading file:  1197
# Reading file:  1198
# Reading file:  1199
# Reading file:  1200
# Reading file:  1201
# Reading file:  1202
# Reading file:  1203
# Reading file:  1204
# Reading file:  1205
# Reading file:  1206
# Reading file:  1207
# Reading file:  1208
# Reading file:  1209
# Reading file:  1210
# Reading file:  1211
# Reading file:  1212
# Reading file:  1213
# Reading file:  1214
# Reading file:  1215
# Reading file:  1216
# Reading file:  1217
# Reading file:  1218
# Reading file:  1219
# Reading file:  1220
# Reading file:  1221
# Reading file:  1222
# Reading file:  1223
# Reading file:  1224
# Reading file:  1225
# Reading file:  1226
# Reading file:  1227
# Reading file:  1228
# Reading file:  1229
# Reading file:  1230
# Reading file:  1231
# Reading file:  1232
# Reading file:  1233
# Reading file:  1234
# Reading file:  1235
# Reading file:  1236
# Reading file:  1237
# Reading file:  1238
# Reading file:  1239
# Reading file:  1240
# Reading file:  1241
# Reading file:  1242
# Reading file:  1243
# Reading file:  1244
# Reading file:  1245
# Reading file:  1246
# Reading file:  1247
# Reading file:  1248
# Reading file:  1249
# Reading file:  1250
# Reading file:  1251
# Reading file:  1252
# Reading file:  1253
# Reading file:  1254
# Reading file:  1255
# Reading file:  1256
# Reading file:  1257
# Reading file:  1258
# Reading file:  1259
# Reading file:  1260
# Reading file:  1261
# Reading file:  1262
# Reading file:  1263
# Reading file:  1264
# Reading file:  1265
# Reading file:  1266
# Reading file:  1267
# Reading file:  1268
# Reading file:  1269
# Reading file:  1270
# Reading file:  1271
# Reading file:  1272
# Reading file:  1273
# Reading file:  1274
# Reading file:  1275
# Reading file:  1276
# Reading file:  1277
# Reading file:  1278
# Reading file:  1279
# Reading file:  1280
# Reading file:  1281
# Reading file:  1282
# Reading file:  1283
# Reading file:  1284
# Reading file:  1285
# Reading file:  1286
# Reading file:  1287
# Reading file:  1288
# Reading file:  1289
# Reading file:  1290
# Reading file:  1291
# Reading file:  1292
# Reading file:  1293
# Reading file:  1294
# Reading file:  1295
# Reading file:  1296
# Reading file:  1297
# Reading file:  1298
# Reading file:  1299
# Reading file:  1300
# Reading file:  1301
# Reading file:  1302
# Reading file:  1303
# Reading file:  1304
# Reading file:  1305
# Reading file:  1306
# Reading file:  1307
# Reading file:  1308
# Reading file:  1309
# Reading file:  1310
# Reading file:  1311
# Reading file:  1312
# Reading file:  1313
# Reading file:  1314
# Reading file:  1315
# Reading file:  1316
# Reading file:  1317
# Reading file:  1318
# Reading file:  1319
# Reading file:  1320
# Reading file:  1321
# Reading file:  1322
# Reading file:  1323
# Reading file:  1324
# Reading file:  1325
# Reading file:  1326
# Reading file:  1327
# Reading file:  1328
# Reading file:  1329
# Reading file:  1330
# Reading file:  1331
# Reading file:  1332
# Reading file:  1333
# Reading file:  1334
# Reading file:  1335
# Reading file:  1336
# Reading file:  1337
# Reading file:  1338
# Reading file:  1339
# Reading file:  1340
# Reading file:  1341
# Reading file:  1342
# Reading file:  1343
# Reading file:  1344
# Reading file:  1345
# Reading file:  1346
# Reading file:  1347
# Reading file:  1348
# Reading file:  1349
# Reading file:  1350
# Reading file:  1351
# Reading file:  1352
# Reading file:  1353
# Reading file:  1354
# Reading file:  1355
# Reading file:  1356
# Reading file:  1357
# Reading file:  1358
# Reading file:  1359
# Reading file:  1360
# Reading file:  1361
# Reading file:  1362
# Reading file:  1363
# Reading file:  1364
# Reading file:  1365
# Reading file:  1366
# Reading file:  1367
# Reading file:  1368
# Reading file:  1369
# Reading file:  1370
# Reading file:  1371
# Reading file:  1372
# Reading file:  1373
# Reading file:  1374
# Reading file:  1375
# Reading file:  1376
# Reading file:  1377
# Reading file:  1378
# Reading file:  1379
# Reading file:  1380
# Reading file:  1381
# Reading file:  1382
# Reading file:  1383
# Reading file:  1384
# Reading file:  1385
# Reading file:  1386
# Reading file:  1387
# Reading file:  1388
# Reading file:  1389
# Reading file:  1390
# Reading file:  1391
# Reading file:  1392
# Reading file:  1393
# Reading file:  1394
# Reading file:  1395
# Reading file:  1396
# Reading file:  1397
# Reading file:  1398
# Reading file:  1399
# Reading file:  1400
# Reading file:  1401
# Reading file:  1402
# Reading file:  1403
# Reading file:  1404
# Reading file:  1405
# Reading file:  1406
# Reading file:  1407
# Reading file:  1408
# Reading file:  1409
# Reading file:  1410
# Reading file:  1411
# Reading file:  1412
# Reading file:  1413
# Reading file:  1414
# Reading file:  1415
# Reading file:  1416
# Reading file:  1417
# Reading file:  1418
# Reading file:  1419
# Reading file:  1420
# Reading file:  1421
# Reading file:  1422
# Reading file:  1423
# Reading file:  1424
# Reading file:  1425
# Reading file:  1426
# Reading file:  1427
# Reading file:  1428
# Reading file:  1429
# Reading file:  1430
# Reading file:  1431
# Reading file:  1432
# Reading file:  1433
# Reading file:  1434
# Reading file:  1435
# Reading file:  1436
# Reading file:  1437
# Reading file:  1438
# Reading file:  1439
# Reading file:  1440
# Reading file:  1441
# Reading file:  1442
# Reading file:  1443
# Reading file:  1444
# Reading file:  1445
# Reading file:  1446
# Reading file:  1447
# Reading file:  1448
# Reading file:  1449
# Reading file:  1450
# Reading file:  1451
# Reading file:  1452
# Reading file:  1453
# Reading file:  1454
# Reading file:  1455
# Reading file:  1456
# Reading file:  1457
# Reading file:  1458
# Reading file:  1459
# Reading file:  1460
# Reading file:  1461
# Reading file:  1462
# Reading file:  1463
# Reading file:  1464
# Reading file:  1465
# Reading file:  1466
# Reading file:  1467
# Reading file:  1468
# Reading file:  1469
# Reading file:  1470
# Reading file:  1471
# Reading file:  1472
# Reading file:  1473
# Reading file:  1474
# Reading file:  1475
# Reading file:  1476
# Reading file:  1477
# Reading file:  1478
# Reading file:  1479
# Reading file:  1480
# Reading file:  1481
# Reading file:  1482
# Reading file:  1483
# Reading file:  1484
# Reading file:  1485
# Reading file:  1486
# Reading file:  1487
# Reading file:  1488
# Reading file:  1489
# Reading file:  1490
# Reading file:  1491
# Reading file:  1492
# Reading file:  1493
# Reading file:  1494
# Reading file:  1495
# Reading file:  1496
# Reading file:  1497
# Reading file:  1498
# Reading file:  1499
# Reading file:  1500
# Reading file:  1501
# Reading file:  1502
# Reading file:  1503
# Reading file:  1504
# Reading file:  1505
# Reading file:  1506
# Reading file:  1507
# Reading file:  1508
# Reading file:  1509
# Reading file:  1510
# Reading file:  1511
# Reading file:  1512
# Reading file:  1513
# Reading file:  1514
# Reading file:  1515
# Reading file:  1516
# Reading file:  1517
# Reading file:  1518
# Reading file:  1519
# Reading file:  1520
# Reading file:  1521
# Reading file:  1522
# Reading file:  1523
# Reading file:  1524
# Reading file:  1525
# Reading file:  1526
# Reading file:  1527
# Reading file:  1528
# Reading file:  1529
# Reading file:  1530
# Reading file:  1531
# Reading file:  1532
# Reading file:  1533
# Reading file:  1534
# Reading file:  1535
# Reading file:  1536
# Reading file:  1537
# Reading file:  1538
# Reading file:  1539
# Reading file:  1540
# Reading file:  1541
# Reading file:  1542
# Reading file:  1543
# Reading file:  1544
# Reading file:  1545
# Reading file:  1546
# Reading file:  1547
# Reading file:  1548
# Reading file:  1549
# Reading file:  1550
# Reading file:  1551
# Reading file:  1552
# Reading file:  1553
# Reading file:  1554
# Reading file:  1555
# Reading file:  1556
# Reading file:  1557
# Reading file:  1558
# Reading file:  1559
# Reading file:  1560
# Reading file:  1561
# Reading file:  1562
# Reading file:  1563
# Reading file:  1564
# Reading file:  1565
# Reading file:  1566
# Reading file:  1567
# Reading file:  1568
# Reading file:  1569
# Reading file:  1570
# Reading file:  1571
# Reading file:  1572
# Reading file:  1573
# Reading file:  1574
# Reading file:  1575
# Reading file:  1576
# Reading file:  1577
# Reading file:  1578
# Reading file:  1579
# Reading file:  1580
# Reading file:  1581
# Reading file:  1582
# Reading file:  1583
# Reading file:  1584
# Reading file:  1585
# Reading file:  1586
# Reading file:  1587
# Reading file:  1588
# Reading file:  1589
# Reading file:  1590
# Reading file:  1591
# Reading file:  1592
# Reading file:  1593
# Reading file:  1594
# Reading file:  1595
# Reading file:  1596
# Reading file:  1597
# Reading file:  1598
# Reading file:  1599
# Reading file:  1600
# Reading file:  1601
# Reading file:  1602
# Reading file:  1603
# Reading file:  1604
# Reading file:  1605
# Reading file:  1606
# Reading file:  1607
# Reading file:  1608
# Reading file:  1609
# Reading file:  1610
# Reading file:  1611
# Reading file:  1612
# Reading file:  1613
# Reading file:  1614
# Reading file:  1615
# Reading file:  1616
# Reading file:  1617
# Reading file:  1618
# Reading file:  1619
# Reading file:  1620
# Reading file:  1621
# Reading file:  1622
# Reading file:  1623
# Reading file:  1624
# Reading file:  1625
# Reading file:  1626
# Reading file:  1627
# Reading file:  1628
# Reading file:  1629
# Reading file:  1630
# Reading file:  1631
# Reading file:  1632
# Reading file:  1633
# Reading file:  1634
# Reading file:  1635
# Reading file:  1636
# Reading file:  1637
# Reading file:  1638
# Reading file:  1639
# Reading file:  1640
# Reading file:  1641
# Reading file:  1642
# Reading file:  1643
# Reading file:  1644
# Reading file:  1645
# Reading file:  1646
# Reading file:  1647
# Reading file:  1648
# Reading file:  1649
# Reading file:  1650
# Reading file:  1651
# Reading file:  1652
# Reading file:  1653
# Reading file:  1654
# Reading file:  1655
# Reading file:  1656
# Reading file:  1657
# Reading file:  1658
# Reading file:  1659
# Reading file:  1660
# Reading file:  1661
# Reading file:  1662
# Reading file:  1663
# Reading file:  1664
# Reading file:  1665
# Reading file:  1666
# Reading file:  1667
# Reading file:  1668
# Reading file:  1669
# Reading file:  1670
# Reading file:  1671
# Reading file:  1672
# Reading file:  1673
# Reading file:  1674
# Reading file:  1675
# Reading file:  1676
# Reading file:  1677
# Reading file:  1678
# Reading file:  1679
# Reading file:  1680
# Reading file:  1681
# Reading file:  1682
# Reading file:  1683
# Reading file:  1684
# Reading file:  1685
# Reading file:  1686
# Reading file:  1687
# Reading file:  1688
# Reading file:  1689
# Reading file:  1690
# Reading file:  1691
# Reading file:  1692
# Reading file:  1693
# Reading file:  1694
# Reading file:  1695
# Reading file:  1696
# Reading file:  1697
# Reading file:  1698
# Reading file:  1699
# Reading file:  1700
# Reading file:  1701
# Reading file:  1702
# Reading file:  1703
# Reading file:  1704
# Reading file:  1705
# Reading file:  1706
# Reading file:  1707
# Reading file:  1708
# Reading file:  1709
# Reading file:  1710
# Reading file:  1711
# Reading file:  1712
# Reading file:  1713
# Reading file:  1714
# Reading file:  1715
# Reading file:  1716
# Reading file:  1717
# Reading file:  1718
# Reading file:  1719
# Reading file:  1720
# Reading file:  1721
# Reading file:  1722
# Reading file:  1723
# Reading file:  1724
# Reading file:  1725
# Reading file:  1726
# Reading file:  1727
# Reading file:  1728
# Reading file:  1729
# Reading file:  1730
# Reading file:  1731
# Reading file:  1732
# Reading file:  1733
# Reading file:  1734
# Reading file:  1735
# Reading file:  1736
# Reading file:  1737
# Reading file:  1738
# Reading file:  1739
# Reading file:  1740
# Reading file:  1741
# Reading file:  1742
# Reading file:  1743
# Reading file:  1744
# Reading file:  1745
# Reading file:  1746
# Reading file:  1747
# Reading file:  1748
# Reading file:  1749
# Reading file:  1750
# Reading file:  1751
# Reading file:  1752
# Reading file:  1753
# Reading file:  1754
# Reading file:  1755
# Reading file:  1756
# Reading file:  1757
# Reading file:  1758
# Reading file:  1759
# Reading file:  1760
# Reading file:  1761
# Reading file:  1762
# Reading file:  1763
# Reading file:  1764
# Reading file:  1765
# Reading file:  1766
# Reading file:  1767
# Reading file:  1768
# Reading file:  1769
# Reading file:  1770
# Reading file:  1771
# Reading file:  1772
# Reading file:  1773
# Reading file:  1774
# Reading file:  1775
# Reading file:  1776
# Reading file:  1777
# Reading file:  1778
# Reading file:  1779
# Reading file:  1780
# Reading file:  1781
# Reading file:  1782
# Reading file:  1783
# Reading file:  1784
# Reading file:  1785
# Reading file:  1786
# Reading file:  1787
# Reading file:  1788
# Reading file:  1789
# Reading file:  1790
# Reading file:  1791
# Reading file:  1792
# Reading file:  1793
# Reading file:  1794
# Reading file:  1795
# Reading file:  1796
# Reading file:  1797
# Reading file:  1798
# Reading file:  1799
# Reading file:  1800
# Reading file:  1801
# Reading file:  1802
# Reading file:  1803
# Reading file:  1804
# Reading file:  1805
# Reading file:  1806
# Reading file:  1807
# Reading file:  1808
# Reading file:  1809
# Reading file:  1810
# Reading file:  1811
# Reading file:  1812
# Reading file:  1813
# Reading file:  1814
# Reading file:  1815
# Reading file:  1816
# Reading file:  1817
# Reading file:  1818
# Reading file:  1819
# Reading file:  1820
# Reading file:  1821
# Reading file:  1822
# Reading file:  1823
# Reading file:  1824
# Reading file:  1825
# Reading file:  1826
# Reading file:  1827
# Reading file:  1828
# Reading file:  1829
# Reading file:  1830
# Reading file:  1831
# Reading file:  1832
# Reading file:  1833
# Reading file:  1834
# Reading file:  1835
# Reading file:  1836
# Reading file:  1837
# Reading file:  1838
# Reading file:  1839
# Reading file:  1840
# Reading file:  1841
# Reading file:  1842
# Reading file:  1843
# Reading file:  1844
# Reading file:  1845
# Reading file:  1846
# Reading file:  1847
# Reading file:  1848
# Reading file:  1849
# Reading file:  1850
# Reading file:  1851
# Reading file:  1852
# Reading file:  1853
# Reading file:  1854
# Reading file:  1855
# Reading file:  1856
# Reading file:  1857
# Reading file:  1858
# Reading file:  1859
# Reading file:  1860
# Reading file:  1861
# Reading file:  1862
# Reading file:  1863
# Reading file:  1864
# Reading file:  1865
# Reading file:  1866
# Reading file:  1867
# Reading file:  1868
# Reading file:  1869
# Reading file:  1870
# Reading file:  1871
# Reading file:  1872
# Reading file:  1873
# Reading file:  1874
# Reading file:  1875
# Reading file:  1876
# Reading file:  1877
# Reading file:  1878
# Reading file:  1879
# Reading file:  1880
# Reading file:  1881
# Reading file:  1882
# Reading file:  1883
# Reading file:  1884
# Reading file:  1885
# Reading file:  1886
# Reading file:  1887
# Reading file:  1888
# Reading file:  1889
# Reading file:  1890
# Reading file:  1891
# Reading file:  1892
# Reading file:  1893
# Reading file:  1894
# Reading file:  1895
# Reading file:  1896
# Reading file:  1897
# Reading file:  1898
# Reading file:  1899
# Reading file:  1900
# Reading file:  1901
# Reading file:  1902
# Reading file:  1903
# Reading file:  1904
# Reading file:  1905
# Reading file:  1906
# Reading file:  1907
# Reading file:  1908
# Reading file:  1909
# Reading file:  1910
# Reading file:  1911
# Reading file:  1912
# Reading file:  1913
# Reading file:  1914
# Reading file:  1915
# Reading file:  1916
# Reading file:  1917
# Reading file:  1918
# Reading file:  1919
# Reading file:  1920
# Reading file:  1921
# Reading file:  1922
# Reading file:  1923
# Reading file:  1924
# Reading file:  1925
# Reading file:  1926
# Reading file:  1927
# Reading file:  1928
# Reading file:  1929
# Reading file:  1930
# Reading file:  1931
# Reading file:  1932
# Reading file:  1933
# Reading file:  1934
# Reading file:  1935
# Reading file:  1936
# Reading file:  1937
# Reading file:  1938
# Reading file:  1939
# Reading file:  1940
# Reading file:  1941
# Reading file:  1942
# Reading file:  1943
# Reading file:  1944
# Reading file:  1945
# Reading file:  1946
# Reading file:  1947
# Reading file:  1948
# Reading file:  1949
# Reading file:  1950
# Reading file:  1951
# Reading file:  1952
# Reading file:  1953
# Reading file:  1954
# Reading file:  1955
# Reading file:  1956
# Reading file:  1957
# Reading file:  1958
# Reading file:  1959
# Reading file:  1960
# Reading file:  1961
# Reading file:  1962
# Reading file:  1963
# Reading file:  1964
# Reading file:  1965
# Reading file:  1966
# Reading file:  1967
# Reading file:  1968
# Reading file:  1969
# Reading file:  1970
# Reading file:  1971
# Reading file:  1972
# Reading file:  1973
# Reading file:  1974
# Reading file:  1975
# Reading file:  1976
# Reading file:  1977
# Reading file:  1978
# Reading file:  1979
# Reading file:  1980
# Reading file:  1981
# Reading file:  1982
# Reading file:  1983
# Reading file:  1984
# Reading file:  1985
# Reading file:  1986
# Reading file:  1987
# Reading file:  1988
# Reading file:  1989
# Reading file:  1990
# Reading file:  1991
# Reading file:  1992
# Reading file:  1993
# Reading file:  1994
# Reading file:  1995
# Reading file:  1996
# Reading file:  1997
# Reading file:  1998
# Reading file:  1999
# Reading file:  2000
# => Processing: Test
# Total file is:  9999
# Reading file:  1
# Reading file:  2
# Reading file:  3
# Reading file:  4
# Reading file:  5
# Reading file:  6
# Reading file:  7
# Reading file:  8
# Reading file:  9
# Reading file:  10
# Reading file:  11
# Reading file:  12
# Reading file:  13
# Reading file:  14
# Reading file:  15
# Reading file:  16
# Reading file:  17
# Reading file:  18
# Reading file:  19
# Reading file:  20
# Reading file:  21
# Reading file:  22
# Reading file:  23
# Reading file:  24
# Reading file:  25
# Reading file:  26
# Reading file:  27
# Reading file:  28
# Reading file:  29
# Reading file:  30
# Reading file:  31
# Reading file:  32
# Reading file:  33
# Reading file:  34
# Reading file:  35
# Reading file:  36
# Reading file:  37
# Reading file:  38
# Reading file:  39
# Reading file:  40
# Reading file:  41
# Reading file:  42
# Reading file:  43
# Reading file:  44
# Reading file:  45
# Reading file:  46
# Reading file:  47
# Reading file:  48
# Reading file:  49
# Reading file:  50
# Reading file:  51
# Reading file:  52
# Reading file:  53
# Reading file:  54
# Reading file:  55
# Reading file:  56
# Reading file:  57
# Reading file:  58
# Reading file:  59
# Reading file:  60
# Reading file:  61
# Reading file:  62
# Reading file:  63
# Reading file:  64
# Reading file:  65
# Reading file:  66
# Reading file:  67
# Reading file:  68
# Reading file:  69
# Reading file:  70
# Reading file:  71
# Reading file:  72
# Reading file:  73
# Reading file:  74
# Reading file:  75
# Reading file:  76
# Reading file:  77
# Reading file:  78
# Reading file:  79
# Reading file:  80
# Reading file:  81
# Reading file:  82
# Reading file:  83
# Reading file:  84
# Reading file:  85
# Reading file:  86
# Reading file:  87
# Reading file:  88
# Reading file:  89
# Reading file:  90
# Reading file:  91
# Reading file:  92
# Reading file:  93
# Reading file:  94
# Reading file:  95
# Reading file:  96
# Reading file:  97
# Reading file:  98
# Reading file:  99
# Reading file:  100
# Reading file:  101
# Reading file:  102
# Reading file:  103
# Reading file:  104
# Reading file:  105
# Reading file:  106
# Reading file:  107
# Reading file:  108
# Reading file:  109
# Reading file:  110
# Reading file:  111
# Reading file:  112
# Reading file:  113
# Reading file:  114
# Reading file:  115
# Reading file:  116
# Reading file:  117
# Reading file:  118
# Reading file:  119
# Reading file:  120
# Reading file:  121
# Reading file:  122
# Reading file:  123
# Reading file:  124
# Reading file:  125
# Reading file:  126
# Reading file:  127
# Reading file:  128
# Reading file:  129
# Reading file:  130
# Reading file:  131
# Reading file:  132
# Reading file:  133
# Reading file:  134
# Reading file:  135
# Reading file:  136
# Reading file:  137
# Reading file:  138
# Reading file:  139
# Reading file:  140
# Reading file:  141
# Reading file:  142
# Reading file:  143
# Reading file:  144
# Reading file:  145
# Reading file:  146
# Reading file:  147
# Reading file:  148
# Reading file:  149
# Reading file:  150
# Reading file:  151
# Reading file:  152
# Reading file:  153
# Reading file:  154
# Reading file:  155
# Reading file:  156
# Reading file:  157
# Reading file:  158
# Reading file:  159
# Reading file:  160
# Reading file:  161
# Reading file:  162
# Reading file:  163
# Reading file:  164
# Reading file:  165
# Reading file:  166
# Reading file:  167
# Reading file:  168
# Reading file:  169
# Reading file:  170
# Reading file:  171
# Reading file:  172
# Reading file:  173
# Reading file:  174
# Reading file:  175
# Reading file:  176
# Reading file:  177
# Reading file:  178
# Reading file:  179
# Reading file:  180
# Reading file:  181
# Reading file:  182
# Reading file:  183
# Reading file:  184
# Reading file:  185
# Reading file:  186
# Reading file:  187
# Reading file:  188
# Reading file:  189
# Reading file:  190
# Reading file:  191
# Reading file:  192
# Reading file:  193
# Reading file:  194
# Reading file:  195
# Reading file:  196
# Reading file:  197
# Reading file:  198
# Reading file:  199
# Reading file:  200
# Reading file:  201
# Reading file:  202
# Reading file:  203
# Reading file:  204
# Reading file:  205
# Reading file:  206
# Reading file:  207
# Reading file:  208
# Reading file:  209
# Reading file:  210
# Reading file:  211
# Reading file:  212
# Reading file:  213
# Reading file:  214
# Reading file:  215
# Reading file:  216
# Reading file:  217
# Reading file:  218
# Reading file:  219
# Reading file:  220
# Reading file:  221
# Reading file:  222
# Reading file:  223
# Reading file:  224
# Reading file:  225
# Reading file:  226
# Reading file:  227
# Reading file:  228
# Reading file:  229
# Reading file:  230
# Reading file:  231
# Reading file:  232
# Reading file:  233
# Reading file:  234
# Reading file:  235
# Reading file:  236
# Reading file:  237
# Reading file:  238
# Reading file:  239
# Reading file:  240
# Reading file:  241
# Reading file:  242
# Reading file:  243
# Reading file:  244
# Reading file:  245
# Reading file:  246
# Reading file:  247
# Reading file:  248
# Reading file:  249
# Reading file:  250
# Reading file:  251
# Reading file:  252
# Reading file:  253
# Reading file:  254
# Reading file:  255
# Reading file:  256
# Reading file:  257
# Reading file:  258
# Reading file:  259
# Reading file:  260
# Reading file:  261
# Reading file:  262
# Reading file:  263
# Reading file:  264
# Reading file:  265
# Reading file:  266
# Reading file:  267
# Reading file:  268
# Reading file:  269
# Reading file:  270
# Reading file:  271
# Reading file:  272
# Reading file:  273
# Reading file:  274
# Reading file:  275
# Reading file:  276
# Reading file:  277
# Reading file:  278
# Reading file:  279
# Reading file:  280
# Reading file:  281
# Reading file:  282
# Reading file:  283
# Reading file:  284
# Reading file:  285
# Reading file:  286
# Reading file:  287
# Reading file:  288
# Reading file:  289
# Reading file:  290
# Reading file:  291
# Reading file:  292
# Reading file:  293
# Reading file:  294
# Reading file:  295
# Reading file:  296
# Reading file:  297
# Reading file:  298
# Reading file:  299
# Reading file:  300
# Reading file:  301
# Reading file:  302
# Reading file:  303
# Reading file:  304
# Reading file:  305
# Reading file:  306
# Reading file:  307
# Reading file:  308
# Reading file:  309
# Reading file:  310
# Reading file:  311
# Reading file:  312
# Reading file:  313
# Reading file:  314
# Reading file:  315
# Reading file:  316
# Reading file:  317
# Reading file:  318
# Reading file:  319
# Reading file:  320
# Reading file:  321
# Reading file:  322
# Reading file:  323
# Reading file:  324
# Reading file:  325
# Reading file:  326
# Reading file:  327
# Reading file:  328
# Reading file:  329
# Reading file:  330
# Reading file:  331
# Reading file:  332
# Reading file:  333
# Reading file:  334
# Reading file:  335
# Reading file:  336
# Reading file:  337
# Reading file:  338
# Reading file:  339
# Reading file:  340
# Reading file:  341
# Reading file:  342
# Reading file:  343
# Reading file:  344
# Reading file:  345
# Reading file:  346
# Reading file:  347
# Reading file:  348
# Reading file:  349
# Reading file:  350
# Reading file:  351
# Reading file:  352
# Reading file:  353
# Reading file:  354
# Reading file:  355
# Reading file:  356
# Reading file:  357
# Reading file:  358
# Reading file:  359
# Reading file:  360
# Reading file:  361
# Reading file:  362
# Reading file:  363
# Reading file:  364
# Reading file:  365
# Reading file:  366
# Reading file:  367
# Reading file:  368
# Reading file:  369
# Reading file:  370
# Reading file:  371
# Reading file:  372
# Reading file:  373
# Reading file:  374
# Reading file:  375
# Reading file:  376
# Reading file:  377
# Reading file:  378
# Reading file:  379
# Reading file:  380
# Reading file:  381
# Reading file:  382
# Reading file:  383
# Reading file:  384
# Reading file:  385
# Reading file:  386
# Reading file:  387
# Reading file:  388
# Reading file:  389
# Reading file:  390
# Reading file:  391
# Reading file:  392
# Reading file:  393
# Reading file:  394
# Reading file:  395
# Reading file:  396
# Reading file:  397
# Reading file:  398
# Reading file:  399
# Reading file:  400
# Reading file:  401
# Reading file:  402
# Reading file:  403
# Reading file:  404
# Reading file:  405
# Reading file:  406
# Reading file:  407
# Reading file:  408
# Reading file:  409
# Reading file:  410
# Reading file:  411
# Reading file:  412
# Reading file:  413
# Reading file:  414
# Reading file:  415
# Reading file:  416
# Reading file:  417
# Reading file:  418
# Reading file:  419
# Reading file:  420
# Reading file:  421
# Reading file:  422
# Reading file:  423
# Reading file:  424
# Reading file:  425
# Reading file:  426
# Reading file:  427
# Reading file:  428
# Reading file:  429
# Reading file:  430
# Reading file:  431
# Reading file:  432
# Reading file:  433
# Reading file:  434
# Reading file:  435
# Reading file:  436
# Reading file:  437
# Reading file:  438
# Reading file:  439
# Reading file:  440
# Reading file:  441
# Reading file:  442
# Reading file:  443
# Reading file:  444
# Reading file:  445
# Reading file:  446
# Reading file:  447
# Reading file:  448
# Reading file:  449
# Reading file:  450
# Reading file:  451
# Reading file:  452
# Reading file:  453
# Reading file:  454
# Reading file:  455
# Reading file:  456
# Reading file:  457
# Reading file:  458
# Reading file:  459
# Reading file:  460
# Reading file:  461
# Reading file:  462
# Reading file:  463
# Reading file:  464
# Reading file:  465
# Reading file:  466
# Reading file:  467
# Reading file:  468
# Reading file:  469
# Reading file:  470
# Reading file:  471
# Reading file:  472
# Reading file:  473
# Reading file:  474
# Reading file:  475
# Reading file:  476
# Reading file:  477
# Reading file:  478
# Reading file:  479
# Reading file:  480
# ...
# Reading file:  1201
# Reading file:  1202
# Reading file:  1203
# Reading file:  1204
# Reading file:  1205
# Reading file:  1206
# Reading file:  1207
# Reading file:  1208
# Reading file:  1209
# Reading file:  1210
# Reading file:  1211
# Reading file:  1212
# Reading file:  1213
# Reading file:  1214
# Reading file:  1215
# Reading file:  1216
# Reading file:  1217
# Reading file:  1218
# Reading file:  1219
# Reading file:  1220
# Reading file:  1221
# Reading file:  1222
# Reading file:  1223
# Reading file:  1224
# Reading file:  1225
# Reading file:  1226
# Reading file:  1227
# Reading file:  1228
# Reading file:  1229
# Reading file:  1230
# Reading file:  1231
# Reading file:  1232
# Reading file:  1233
# Reading file:  1234
# Reading file:  1235
# Reading file:  1236
# Reading file:  1237
# Reading file:  1238
# Reading file:  1239
# Reading file:  1240
# Reading file:  1241
# Reading file:  1242
# Reading file:  1243
# Reading file:  1244
# Reading file:  1245
# Reading file:  1246
# Reading file:  1247
# Reading file:  1248
# Reading file:  1249
# Reading file:  1250
# Reading file:  1251
# Reading file:  1252
# Reading file:  1253
# Reading file:  1254
# Reading file:  1255
# Reading file:  1256
# Reading file:  1257
# Reading file:  1258
# Reading file:  1259
# Reading file:  1260
# Reading file:  1261
# Reading file:  1262
# Reading file:  1263
# Reading file:  1264
# Reading file:  1265
# Reading file:  1266
# Reading file:  1267
# Reading file:  1268
# Reading file:  1269
# Reading file:  1270
# Reading file:  1271
# Reading file:  1272
# Reading file:  1273
# Reading file:  1274
# Reading file:  1275
# Reading file:  1276
# Reading file:  1277
# Reading file:  1278
# Reading file:  1279
# Reading file:  1280
# Reading file:  1281
# Reading file:  1282
# Reading file:  1283
# Reading file:  1284
# Reading file:  1285
# Reading file:  1286
# Reading file:  1287
# Reading file:  1288
# Reading file:  1289
# Reading file:  1290
# Reading file:  1291
# Reading file:  1292
# Reading file:  1293
# Reading file:  1294
# Reading file:  1295
# Reading file:  1296
# Reading file:  1297
# Reading file:  1298
# Reading file:  1299
# Reading file:  1300
# Reading file:  1301
# Reading file:  1302
# Reading file:  1303
# Reading file:  1304
# Reading file:  1305
# Reading file:  1306
# Reading file:  1307
# Reading file:  1308
# Reading file:  1309
# Reading file:  1310
# Reading file:  1311
# Reading file:  1312
# Reading file:  1313
# Reading file:  1314
# Reading file:  1315
# Reading file:  1316
# Reading file:  1317
# Reading file:  1318
# Reading file:  1319
# Reading file:  1320
# Reading file:  1321
# Reading file:  1322
# Reading file:  1323
# Reading file:  1324
# Reading file:  1325
# Reading file:  1326
# Reading file:  1327
# Reading file:  1328
# Reading file:  1329
# Reading file:  1330
# Reading file:  1331
# Reading file:  1332
# Reading file:  1333
# Reading file:  1334
# Reading file:  1335
# Reading file:  1336
# Reading file:  1337
# Reading file:  1338
# Reading file:  1339
# Reading file:  1340
# Reading file:  1341
# Reading file:  1342
# Reading file:  1343
# Reading file:  1344
# Reading file:  1345
# Reading file:  1346
# Reading file:  1347
# Reading file:  1348
# Reading file:  1349
# Reading file:  1350
# Reading file:  1351
# Reading file:  1352
# Reading file:  1353
# Reading file:  1354
# Reading file:  1355
# Reading file:  1356
# Reading file:  1357
# Reading file:  1358
# Reading file:  1359
# Reading file:  1360
# Reading file:  1361
# Reading file:  1362
# Reading file:  1363
# Reading file:  1364
# Reading file:  1365
# Reading file:  1366
# Reading file:  1367
# Reading file:  1368
# Reading file:  1369
# Reading file:  1370
# Reading file:  1371
# Reading file:  1372
# Reading file:  1373
# Reading file:  1374
# Reading file:  1375
# Reading file:  1376
# Reading file:  1377
# Reading file:  1378
# Reading file:  1379
# Reading file:  1380
# Reading file:  1381
# Reading file:  1382
# Reading file:  1383
# Reading file:  1384
# Reading file:  1385
# Reading file:  1386
# Reading file:  1387
# Reading file:  1388
# Reading file:  1389
# Reading file:  1390
# Reading file:  1391
# Reading file:  1392
# Reading file:  1393
# Reading file:  1394
# Reading file:  1395
# Reading file:  1396
# Reading file:  1397
# Reading file:  1398
# Reading file:  1399
# Reading file:  1400
# Reading file:  1401
# Reading file:  1402
# Reading file:  1403
# Reading file:  1404
# Reading file:  1405
# Reading file:  1406
# Reading file:  1407
# Reading file:  1408
# Reading file:  1409
# Reading file:  1410
# Reading file:  1411
# Reading file:  1412
# Reading file:  1413
# Reading file:  1414
# Reading file:  1415
# Reading file:  1416
# Reading file:  1417
# Reading file:  1418
# Reading file:  1419
# Reading file:  1420
# Reading file:  1421
# Reading file:  1422
# Reading file:  1423
# Reading file:  1424
# Reading file:  1425
# Reading file:  1426
# Reading file:  1427
# Reading file:  1428
# Reading file:  1429
# Reading file:  1430
# Reading file:  1431
# Reading file:  1432
# Reading file:  1433
# Reading file:  1434
# Reading file:  1435
# Reading file:  1436
# Reading file:  1437
# Reading file:  1438
# Reading file:  1439
# Reading file:  1440
# Reading file:  1441
# Reading file:  1442
# Reading file:  1443
# Reading file:  1444
# Reading file:  1445
# Reading file:  1446
# Reading file:  1447
# Reading file:  1448
# Reading file:  1449
# Reading file:  1450
# Reading file:  1451
# Reading file:  1452
# Reading file:  1453
# Reading file:  1454
# Reading file:  1455
# Reading file:  1456
# Reading file:  1457
# Reading file:  1458
# Reading file:  1459
# Reading file:  1460
# Reading file:  1461
# Reading file:  1462
# Reading file:  1463
# Reading file:  1464
# Reading file:  1465
# Reading file:  1466
# Reading file:  1467
# Reading file:  1468
# Reading file:  1469
# Reading file:  1470
# Reading file:  1471
# Reading file:  1472
# Reading file:  1473
# Reading file:  1474
# Reading file:  1475
# Reading file:  1476
# Reading file:  1477
# Reading file:  1478
# Reading file:  1479
# Reading file:  1480
# Reading file:  1481
# Reading file:  1482
# Reading file:  1483
# Reading file:  1484
# Reading file:  1485
# Reading file:  1486
# Reading file:  1487
# Reading file:  1488
# Reading file:  1489
# Reading file:  1490
# Reading file:  1491
# Reading file:  1492
# Reading file:  1493
# Reading file:  1494
# Reading file:  1495
# Reading file:  1496
# Reading file:  1497
# Reading file:  1498
# Reading file:  1499
# Reading file:  1500
# Reading file:  1501
# Reading file:  1502
# Reading file:  1503
# Reading file:  1504
# Reading file:  1505
# Reading file:  1506
# Reading file:  1507
# Reading file:  1508
# Reading file:  1509
# Reading file:  1510
# Reading file:  1511
# Reading file:  1512
# Reading file:  1513
# Reading file:  1514
# Reading file:  1515
# Reading file:  1516
# Reading file:  1517
# Reading file:  1518
# Reading file:  1519
# Reading file:  1520
# Reading file:  1521
# Reading file:  1522
# Reading file:  1523
# Reading file:  1524
# Reading file:  1525
# Reading file:  1526
# Reading file:  1527
# Reading file:  1528
# Reading file:  1529
# Reading file:  1530
# Reading file:  1531
# Reading file:  1532
# Reading file:  1533
# Reading file:  1534
# Reading file:  1535
# Reading file:  1536
# Reading file:  1537
# Reading file:  1538
# Reading file:  1539
# Reading file:  1540
# Reading file:  1541
# Reading file:  1542
# Reading file:  1543
# Reading file:  1544
# Reading file:  1545
# Reading file:  1546
# Reading file:  1547
# Reading file:  1548
# Reading file:  1549
# Reading file:  1550
# Reading file:  1551
# Reading file:  1552
# Reading file:  1553
# Reading file:  1554
# Reading file:  1555
# Reading file:  1556
# Reading file:  1557
# Reading file:  1558
# Reading file:  1559
# Reading file:  1560
# Reading file:  1561
# Reading file:  1562
# Reading file:  1563
# Reading file:  1564
# Reading file:  1565
# Reading file:  1566
# Reading file:  1567
# Reading file:  1568
# Reading file:  1569
# Reading file:  1570
# Reading file:  1571
# Reading file:  1572
# Reading file:  1573
# Reading file:  1574
# Reading file:  1575
# Reading file:  1576
# Reading file:  1577
# Reading file:  1578
# Reading file:  1579
# Reading file:  1580
# Reading file:  1581
# Reading file:  1582
# Reading file:  1583
# Reading file:  1584
# Reading file:  1585
# Reading file:  1586
# Reading file:  1587
# Reading file:  1588
# Reading file:  1589
# Reading file:  1590
# Reading file:  1591
# Reading file:  1592
# Reading file:  1593
# Reading file:  1594
# Reading file:  1595
# Reading file:  1596
# Reading file:  1597
# Reading file:  1598
# Reading file:  1599
# Reading file:  1600
# Reading file:  1601
# Reading file:  1602
# Reading file:  1603
# Reading file:  1604
# Reading file:  1605
# Reading file:  1606
# Reading file:  1607
# Reading file:  1608
# Reading file:  1609
# Reading file:  1610
# Reading file:  1611
# Reading file:  1612
# Reading file:  1613
# Reading file:  1614
# Reading file:  1615
# Reading file:  1616
# Reading file:  1617
# Reading file:  1618
# Reading file:  1619
# Reading file:  1620
# Reading file:  1621
# Reading file:  1622
# Reading file:  1623
# Reading file:  1624
# Reading file:  1625
# Reading file:  1626
# Reading file:  1627
# Reading file:  1628
# Reading file:  1629
# Reading file:  1630
# Reading file:  1631
# Reading file:  1632
# Reading file:  1633
# Reading file:  1634
# Reading file:  1635
# Reading file:  1636
# Reading file:  1637
# Reading file:  1638
# Reading file:  1639
# Reading file:  1640
# Reading file:  1641
# Reading file:  1642
# Reading file:  1643
# Reading file:  1644
# Reading file:  1645
# Reading file:  1646
# Reading file:  1647
# Reading file:  1648
# Reading file:  1649
# Reading file:  1650
# Reading file:  1651
# Reading file:  1652
# Reading file:  1653
# Reading file:  1654
# Reading file:  1655
# Reading file:  1656
# Reading file:  1657
# Reading file:  1658
# Reading file:  1659
# Reading file:  1660
# Reading file:  1661
# Reading file:  1662
# Reading file:  1663
# Reading file:  1664
# Reading file:  1665
# Reading file:  1666
# Reading file:  1667
# Reading file:  1668
# Reading file:  1669
# Reading file:  1670
# Reading file:  1671
# Reading file:  1672
# Reading file:  1673
# Reading file:  1674
# Reading file:  1675
# Reading file:  1676
# Reading file:  1677
# Reading file:  1678
# Reading file:  1679
# Reading file:  1680
# Reading file:  1681
# Reading file:  1682
# Reading file:  1683
# Reading file:  1684
# Reading file:  1685
# Reading file:  1686
# Reading file:  1687
# Reading file:  1688
# Reading file:  1689
# Reading file:  1690
# Reading file:  1691
# Reading file:  1692
# Reading file:  1693
# Reading file:  1694
# Reading file:  1695
# Reading file:  1696
# Reading file:  1697
# Reading file:  1698
# Reading file:  1699
# Reading file:  1700
# Reading file:  1701
# Reading file:  1702
# Reading file:  1703
# Reading file:  1704
# Reading file:  1705
# Reading file:  1706
# Reading file:  1707
# Reading file:  1708
# Reading file:  1709
# Reading file:  1710
# Reading file:  1711
# Reading file:  1712
# Reading file:  1713
# Reading file:  1714
# Reading file:  1715
# Reading file:  1716
# Reading file:  1717
# Reading file:  1718
# Reading file:  1719
# Reading file:  1720
# Reading file:  1721
# Reading file:  1722
# Reading file:  1723
# Reading file:  1724
# Reading file:  1725
# Reading file:  1726
# Reading file:  1727
# Reading file:  1728
# Reading file:  1729
# Reading file:  1730
# Reading file:  1731
# Reading file:  1732
# Reading file:  1733
# Reading file:  1734
# Reading file:  1735
# Reading file:  1736
# Reading file:  1737
# Reading file:  1738
# Reading file:  1739
# Reading file:  1740
# Reading file:  1741
# Reading file:  1742
# Reading file:  1743
# Reading file:  1744
# Reading file:  1745
# Reading file:  1746
# Reading file:  1747
# Reading file:  1748
# Reading file:  1749
# Reading file:  1750
# Reading file:  1751
# Reading file:  1752
# Reading file:  1753
# Reading file:  1754
# Reading file:  1755
# Reading file:  1756
# Reading file:  1757
# Reading file:  1758
# Reading file:  1759
# Reading file:  1760
# Reading file:  1761
# Reading file:  1762
# Reading file:  1763
# Reading file:  1764
# Reading file:  1765
# Reading file:  1766
# Reading file:  1767
# Reading file:  1768
# Reading file:  1769
# Reading file:  1770
# Reading file:  1771
# Reading file:  1772
# Reading file:  1773
# Reading file:  1774
# Reading file:  1775
# Reading file:  1776
# Reading file:  1777
# Reading file:  1778
# Reading file:  1779
# Reading file:  1780
# Reading file:  1781
# Reading file:  1782
# Reading file:  1783
# Reading file:  1784
# Reading file:  1785
# Reading file:  1786
# Reading file:  1787
# Reading file:  1788
# Reading file:  1789
# Reading file:  1790
# Reading file:  1791
# Reading file:  1792
# Reading file:  1793
# Reading file:  1794
# Reading file:  1795
# Reading file:  1796
# Reading file:  1797
# Reading file:  1798
# Reading file:  1799
# Reading file:  1800
# Reading file:  1801
# Reading file:  1802
# Reading file:  1803
# Reading file:  1804
# Reading file:  1805
# Reading file:  1806
# Reading file:  1807
# Reading file:  1808
# Reading file:  1809
# Reading file:  1810
# Reading file:  1811
# Reading file:  1812
# Reading file:  1813
# Reading file:  1814
# Reading file:  1815
# Reading file:  1816
# Reading file:  1817
# Reading file:  1818
# Reading file:  1819
# Reading file:  1820
# Reading file:  1821
# Reading file:  1822
# Reading file:  1823
# Reading file:  1824
# Reading file:  1825
# Reading file:  1826
# Reading file:  1827
# Reading file:  1828
# Reading file:  1829
# Reading file:  1830
# Reading file:  1831
# Reading file:  1832
# Reading file:  1833
# Reading file:  1834
# Reading file:  1835
# Reading file:  1836
# Reading file:  1837
# Reading file:  1838
# Reading file:  1839
# Reading file:  1840
# Reading file:  1841
# Reading file:  1842
# Reading file:  1843
# Reading file:  1844
# Reading file:  1845
# Reading file:  1846
# Reading file:  1847
# Reading file:  1848
# Reading file:  1849
# Reading file:  1850
# Reading file:  1851
# Reading file:  1852
# Reading file:  1853
# Reading file:  1854
# Reading file:  1855
# Reading file:  1856
# Reading file:  1857
# Reading file:  1858
# Reading file:  1859
# Reading file:  1860
# Reading file:  1861
# Reading file:  1862
# Reading file:  1863
# Reading file:  1864
# Reading file:  1865
# Reading file:  1866
# Reading file:  1867
# Reading file:  1868
# Reading file:  1869
# Reading file:  1870
# Reading file:  1871
# Reading file:  1872
# Reading file:  1873
# Reading file:  1874
# Reading file:  1875
# Reading file:  1876
# Reading file:  1877
# Reading file:  1878
# Reading file:  1879
# Reading file:  1880
# Reading file:  1881
# Reading file:  1882
# Reading file:  1883
# Reading file:  1884
# Reading file:  1885
# Reading file:  1886
# Reading file:  1887
# Reading file:  1888
# Reading file:  1889
# Reading file:  1890
# Reading file:  1891
# Reading file:  1892
# Reading file:  1893
# Reading file:  1894
# Reading file:  1895
# Reading file:  1896
# Reading file:  1897
# Reading file:  1898
# Reading file:  1899
# Reading file:  1900
# Reading file:  1901
# Reading file:  1902
# Reading file:  1903
# Reading file:  1904
# Reading file:  1905
# Reading file:  1906
# Reading file:  1907
# Reading file:  1908
# Reading file:  1909
# Reading file:  1910
# Reading file:  1911
# Reading file:  1912
# Reading file:  1913
# Reading file:  1914
# Reading file:  1915
# Reading file:  1916
# Reading file:  1917
# Reading file:  1918
# Reading file:  1919
# Reading file:  1920
# Reading file:  1921
# Reading file:  1922
# Reading file:  1923
# Reading file:  1924
# Reading file:  1925
# Reading file:  1926
# Reading file:  1927
# Reading file:  1928
# Reading file:  1929
# Reading file:  1930
# Reading file:  1931
# Reading file:  1932
# Reading file:  1933
# Reading file:  1934
# Reading file:  1935
# Reading file:  1936
# Reading file:  1937
# Reading file:  1938
# Reading file:  1939
# Reading file:  1940
# Reading file:  1941
# Reading file:  1942
# Reading file:  1943
# Reading file:  1944
# Reading file:  1945
# Reading file:  1946
# Reading file:  1947
# Reading file:  1948
# Reading file:  1949
# Reading file:  1950
# Reading file:  1951
# Reading file:  1952
# Reading file:  1953
# Reading file:  1954
# Reading file:  1955
# Reading file:  1956
# Reading file:  1957
# Reading file:  1958
# Reading file:  1959
# Reading file:  1960
# Reading file:  1961
# Reading file:  1962
# Reading file:  1963
# Reading file:  1964
# Reading file:  1965
# Reading file:  1966
# Reading file:  1967
# Reading file:  1968
# Reading file:  1969
# Reading file:  1970
# Reading file:  1971
# Reading file:  1972
# Reading file:  1973
# Reading file:  1974
# Reading file:  1975
# Reading file:  1976
# Reading file:  1977
# Reading file:  1978
# Reading file:  1979
# Reading file:  1980
# Reading file:  1981
# Reading file:  1982
# Reading file:  1983
# Reading file:  1984
# Reading file:  1985
# Reading file:  1986
# Reading file:  1987
# Reading file:  1988
# Reading file:  1989
# Reading file:  1990
# Reading file:  1991
# Reading file:  1992
# Reading file:  1993
# Reading file:  1994
# Reading file:  1995
# Reading file:  1996
# Reading file:  1997
# Reading file:  1998
# Reading file:  1999
# Reading file:  2000

# %%
#
#
# ------- Your Code -------
#
#
# def max_list_lenght(list_2d):
#     max_len = 0
#     for i in list_2d:
#         if len(i)> max_len:
#             max_len = len(i)
#     return max_len
        

# train_x , train_y = [x for x,_ in train_data],[y for _,y in train_data]
# test_x , test_y = [x for x,_ in test_data],[y for _,y in test_data]

# max_len = max_list_lenght(train_x)
# train_x = [x + [0] * (max_len - len(x)) for x in train_x]
# #print(train_x)
# train_x = torch.tensor(train_x)


# train_y = torch.FloatTensor(train_y)
# test_x = [x + [0] * (max_len - len(x)) for x in test_x]
# test_x = torch.FloatTensor(test_x)
# test_y = torch.FloatTensor(test_y)

train_y_torch = torch.FloatTensor(train_y_encoded)
test_y_torch = torch.FloatTensor(test_y_encoded)

#print(train_y)

# Suggestions: 
#
# (a) You can use torch.utils.data.TensorDataset to represent the tensors you created previously
trainset = TensorDataset(train_x_torch, train_y_encoded)  
testset = TensorDataset(test_x_torch, test_y_encoded)
#
# (b) Store your datasets to disk so that you do not need to precompute it every time
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-1aa277e919fa> in <module>
#      34 #
#      35 # (a) You can use torch.utils.data.TensorDataset to represent the tensors you created previously
# ---> 36 trainset = TensorDataset(train_x_torch, train_y_encoded)
#      37 testset = TensorDataset(test_x_torch, test_y_encoded)
#      38 #
#
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\torch\utils\data\dataset.py in __init__(self, *tensors)
#     155
#     156     def __init__(self, *tensors):
# --> 157         assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors)
#     158         self.tensors = tensors
#     159
#
# C:\ProgramData\Miniconda3\envs\DSP\lib\site-packages\torch\utils\data\dataset.py in <genexpr>(.0)
#     155
#     156     def __init__(self, *tensors):
# --> 157         assert all(tensors[0].size(0) == tensor.size(0) for tensor in tensors)
#     158         self.tensors = tensors
#     159
#
# TypeError: 'int' object is not callable

# %% [markdown]
# # 2. Train Model
#
# You will now train an ML model on the vectorized datasets you created previously.
#
# _Note_: Although I often refer to each input as a 'vector' for simplicity, each of your inputs can also be higher dimensional tensors.

# %% [markdown]
# ## 2.a. Helpers

# %%
# Feel free to edit anything in this block

def evaluate_preds(y_gt, y_pred):
    y_gt = [np.where(r==1)[0][0] for r in y_gt]
    y_pred = [np.where(r==1)[0][0] for r in y_pred]

    return 0


def another_helper(question):
    return 42


def save_model(model, out_path):
    torch.save(model.state_dict(), out_path)


def save_data(eval_data, out_path):
    with open(out_path, 'wb') as handle:
        pickle.dump(eval_data, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## 2.b. Define Model

# %% [markdown]
# Describe your model here.

# %%
# Feel free to edit anything in this block

class NetDNN(nn.Module):
    def __init__(self, in_dims, h1, h2, out_dims):
        super(NetDNN, self).__init__()
        # Layer definitions
        self.fc1 = nn.Linear(in_dims, h1)
        self.fc2 = nn.Linear(h1,h2)
        self.fc3 = nn.Linear(h2,out_dims)

    def forward(self, x):
        # Forward pass
        x =  F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x =  F.softmax(self.fc3(x))
        return x

# %% [markdown]
# ## 2.c. Set Hyperparameters

# %%
# Define your hyperparameters here

in_dims = trainset[0][0].shape[0]
print('Input di',in_dims)
h1, h2 = 128, 128
out_dims = len(index_class)
print('Output dim', out_dims)

# Optimization
n_epochs = 25
batch_size = 32 # Originally 32
lr = 1e-2
momentum = 0.9
# Out:
# Input di 157990
# Output dim 10

# %% [markdown]
# ## 2.d. Train your Model

# %%
# Feel free to edit anything in this block

net = NetDNN(in_dims, h1, h2, out_dims)
net.train()

criterion = nn.CrossEntropyLoss()
# Optimizer
optimizer = optim.SGD(net.parameters(), lr=lr, momentum=momentum)

# Data Loaders
trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True)
testloader = DataLoader(testset, batch_size=batch_size, shuffle=False)

dataloader = {'train': trainloader,'val': testloader}

# Etc.

# %%
#
#
# ------- Your Code -------
#
# Example:
from livelossplot import PlotLosses

def train_model(model,criterion, optimizer, n_epochs):
    eval_data = {}
    model = model.to(device)
    live_plot = PlotLosses()
    epoch_list = []
    train_loss_list = []
    test_loss_list = []
    train_acc_list = []
    test_acc_list = []
    for epoch in range(n_epochs):
        logs = {}
        for phase in ['train','val']:
            if phase == 'train':
                model.train()
            if phase == 'val':
                model.eval()

            running_loss = 0.0
            ruuning_corrects = 0


            for inputs, labels in dataloader[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = model(inputs.float())
                labels = labels.to(device=device, dtype=torch.int64)
                loss = criterion(outputs, torch.max(labels, 1)[1])

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()


            _, preds = torch.max(outputs, 1)

            running_loss += loss.detach()* inputs.size(0)
            labels_nonhot =  torch.tensor([np.where(r==1)[0][0] for r in labels.data])

            ruuning_corrects += torch.sum(preds == labels_nonhot)

            epoch_loss = running_loss / len(dataloader[phase].dataset)
            epoch_acc = ruuning_corrects.float() / len(dataloader[phase].dataset)
      
            prefix = ''
            if phase == 'val':
                prefix = 'val_'

            logs[prefix + 'log_loss'] = epoch_loss.item()
            logs[prefix + 'accuracy'] = epoch_acc.item()
            
        epoch_list.append(epoch)
        train_loss_list.append(logs['log_loss'])
        test_loss_list.append(logs['val_log_loss'])
        train_acc_list.append(logs['accuracy'])
        test_acc_list.append(logs['val_accuracy'])
        live_plot.update(logs)
        live_plot.draw()
    eval_data['epoch'] = epoch_list
    eval_data['train_loss'] = train_loss_list
    eval_data['test_loss'] = test_loss_list
    eval_data['train_acc'] = train_acc_list
    eval_data['test_acc'] = test_acc_list
    
    return model, eval_data

# %%
#Print training loss.

model, eval_data =  train_model(net, criterion, optimizer,n_epochs)
# Out:
# log_loss:
# training   (min:    0.016, max:    0.019, cur:    0.018)
# validation (min:    0.018, max:    0.018, cur:    0.018)
#
# accuracy:
# training   (min:    0.001, max:    0.004, cur:    0.002)
# validation (min:    0.002, max:    0.002, cur:    0.002)

# %% [markdown]
# ## 2.e. Evaluate model

# %%
#
#
# ------- Your Code -------
#
# 





for dataiter in testloader:
    features, labels = dataiter
    outputs = net(features)
    _ ,outputs = torch.max(outputs, 1)
    _, labels_nonhot =  torch.max(labels,1)
    accuracy = accuracy +  torch.sum(outputs == labels_nonhot)


accuracy = 100 * accuracy / len(test_y)
print('Overall test accuracy(%) : ', accuracy.item())
# Out:
# /Users/mak/python3-venv/mlcysec/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   from ipykernel import kernelapp as app
# Overall test accuracy(%) :  29

# %% [markdown]
# ## 2.f. Save Model + Data

# %%
# Feel free to edit anything in this block

expt_name = 'model:mlp_tokenizer:foo_key3:val3_key4:val4'

model_out_path = '{}.checkpoint.pth'.format(expt_name)
save_model(model, model_out_path)

eval_out_path = '{}.eval.pickle'.format(expt_name)
print(eval_out_path)
save_data(eval_data, eval_out_path)
# Out:
# model:mlp_tokenizer:foo_key3:val3_key4:val4.eval.pickle

# %% [markdown]
# ---

# %% [markdown]
# # 3. Analysis

# %% [markdown]
# ## 3.a. Summary: Main Results
#
# If you tried other approaches, summarize their results here.

# %% [markdown]
# |        | Input Representation | Model | Optimizer | Validation Metric | Test Metric |
# |--------|----------------------|-------|-----------|-------------------|-------------|
# | Model1 | Unigram tokens       | MLP   | SGD       | 12.34 %           | 23.45%      |
# | Model2 (this notebook) |                      |       |           |                   |             |
# | ...    |                      |       |           |                   |             |

# %% [markdown]
# ## 3.b. Discussion
#
# Enter your final summary here.
#
# For instance, you can address:
# - What was the performance you obtained with the simplest approach?
# - Which vectorized input representations helped more than the others?
# - Which malwares are difficult to detect and why?
# - Which approach do you recommend to perform malware classification?
